# %% [raw]
# Project Name - PhonePe Transaction Insights

# %% [raw]
# Project Type  - EDA / Dashboard Visualization
# Contribution  - Individual Project

# %% [raw]
# Project Summary -
#
# PhonePe is one of India's leading digital payment platforms. With the increasing adoption of UPI-based transactions, massive volumes of payment data are generated across India. This project explores the PhonePe Pulse open-source dataset to uncover key insights into digital payment behavior. The dataset is structured as JSON files organized by state, year, and quarter, and covers three main areas: aggregated transactions, user activity, and insurance.
#
# The project workflow includes:
# - Cloning the PhonePe Pulse GitHub repository
# - Parsing JSON files into pandas DataFrames
# - Exploratory data analysis (EDA) using charts and maps
# - Identifying top states, districts, and pin codes by payment volume and user activity
# - Visualizing trends using Python libraries (Matplotlib, Plotly, Seaborn)
# - Building an interactive dashboard using Streamlit
#
# Key use cases addressed:
# - Customer segmentation by region
# - Market insights for product development
# - Performance benchmarking across regions
# - Insurance penetration trends
#
# This EDA-focused project demonstrates SQL-free insights generation using Python, strong data handling, and visualization capabilities.

# %% [raw]
# GitHub Link -

# %% [raw]
# Problem Statement-
#
# With the rise of digital payments in India, it is crucial to derive actionable insights from transaction data to improve services and user targeting. This project analyzes PhonePe's data to uncover trends in payments, user activity, and insurance usage across states, districts, and pin codes. The data is extracted from the open-source PhonePe Pulse GitHub repository.

# %% [raw]
# LET'S BEGIN

# %% [raw]
# 1] I have cloned the data from a GitHub repository(https://github.com/PhonePe/pulse) (JSON format) in the local folder(C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data)

# %% [raw]
# 2]loaded json format data in database .As below

# %%
import json
import sqlite3
import os
import glob # For easily finding files with a specific pattern


json_root_dir = "C:\\Users\\mukta\\OneDrive\\Desktop\\Phonepay\\pulse\\data\\aggregated\\insurance\\country\\india"

# Define the path for your SQLite database
db_file_path = "ag_insurance_data.db" 

def setup_database(db_path):
    """Sets up the SQLite database tables."""
    conn = None
    try:
        conn = sqlite3.connect(db_path)
        cursor = conn.cursor()

        # 1. Create the Transactions table
        cursor.execute('''
            CREATE TABLE IF NOT EXISTS Transactions (
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                name TEXT,
                from_timestamp INTEGER,
                to_timestamp INTEGER,
                response_timestamp INTEGER,
                source_file TEXT -- Add a column to track which file this data came from
            )
        ''')

        # 2. Create the PaymentInstruments table
        cursor.execute('''
            CREATE TABLE IF NOT EXISTS PaymentInstruments (
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                transaction_id INTEGER,
                type TEXT,
                count INTEGER,
                amount REAL,
                FOREIGN KEY (transaction_id) REFERENCES Transactions(id)
            )
        ''')
        conn.commit()
        print("Database tables created/ensured.")
    except sqlite3.Error as e:
        print(f"Error setting up database: {e}")
    finally:
        if conn:
            conn.close()

def insert_json_data(json_data, source_filename, db_path):
    """
    Inserts data from a single parsed JSON object into the SQLite database.
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file_path)
        cursor = conn.cursor()

        # Extract top-level data
        success = json_data.get("success")
        code = json_data.get("code")
        response_timestamp = json_data.get("responseTimestamp")
        main_data = json_data.get("data", {})
        from_ts = main_data.get("from")
        to_ts = main_data.get("to")
        transaction_data_list = main_data.get("transactionData", [])

        # Insert into Transactions table
        if transaction_data_list:
            for transaction_item in transaction_data_list:
                transaction_name = transaction_item.get("name")

                cursor.execute('''
                    INSERT INTO Transactions (name, from_timestamp, to_timestamp, response_timestamp, source_file)
                    VALUES (?, ?, ?, ?, ?)
                ''', (transaction_name, from_ts, to_ts, response_timestamp, source_filename))
                transaction_id = cursor.lastrowid # Get the ID of the newly inserted row

                # Insert into PaymentInstruments table
                payment_instruments = transaction_item.get("paymentInstruments", [])
                for pi in payment_instruments:
                    pi_type = pi.get("type")
                    pi_count = pi.get("count")
                    pi_amount = pi.get("amount")

                    cursor.execute('''
                        INSERT INTO PaymentInstruments (transaction_id, type, count, amount)
                        VALUES (?, ?, ?, ?)
                    ''', (transaction_id, pi_type, pi_count, pi_amount))
            conn.commit()
            print(f"Successfully inserted data from '{source_filename}'.")
        else:
            print(f"No 'transactionData' found in '{source_filename}'. Skipping data insertion.")

    except sqlite3.Error as e:
        print(f"Error inserting data from '{source_filename}': {e}")
        if conn:
            conn.rollback() # Rollback changes for this file if an error occurs
    finally:
        if conn:
            conn.close()

def load_folder_of_jsons_to_sqlite(folder_path, db_path):
    """
    Loads all JSON files from a specified folder and its subfolders into a SQLite database.
    """
    setup_database(db_path) # Ensure tables are set up before starting insertions

    # Use glob to find all .json files in the folder and its subfolders
    # ** means look in subdirectories, * means any filename
    json_files = glob.glob(os.path.join(folder_path, '**', '*.json'), recursive=True)

    if not json_files:
        print(f"No JSON files found in '{folder_path}' or its subdirectories.")
        return

    print(f"Found {len(json_files)} JSON files. Starting insertion...")
    for json_file in json_files:
        print(f"Processing: {json_file}")
        try:
            with open(json_file, 'r', encoding='utf-8') as f:
                data = json.load(f)
            # Pass the basename of the file for tracking
            insert_json_data(data, os.path.basename(json_file), db_path)
        except FileNotFoundError:
            print(f"Error: JSON file not found (should not happen here): {json_file}")
        except json.JSONDecodeError:
            print(f"Error: Could not decode JSON from {json_file}. Skipping.")
        except PermissionError:
            print(f"Permission denied for file: {json_file}. Skipping.")


# --- Main Execution ---
if __name__ == "__main__":
   
    # The glob pattern will find all .json files recursively from json_root_dir.

    load_folder_of_jsons_to_sqlite(json_root_dir, db_file_path)

    #Verify data
    print("\nVerifying data from all files...")
    conn = sqlite3.connect(db_file_path)
    cursor = conn.cursor()

    cursor.execute("SELECT * FROM Transactions LIMIT 5") # Limit to 5 rows for brevity
    print("\nTransactions Table (first 5 rows):")
    for row in cursor.fetchall():
        print(row)

    cursor.execute("SELECT * FROM PaymentInstruments LIMIT 5") # Limit to 5 rows for brevity
    print("\nPaymentInstruments Table (first 5 rows):")
    for row in cursor.fetchall():
        print(row)

    # Example: How many transactions from each file?
    cursor.execute("SELECT source_file, COUNT(*) FROM Transactions GROUP BY source_file")
    print("\nTransactions per source file:")
    for row in cursor.fetchall():
        print(row)


    conn.close()
# Out:
# Database tables created/ensured.
# Found 703 JSON files. Starting insertion...
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\2020\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\2020\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\2020\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\2021\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\2021\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\2021\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\2021\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\2022\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\2022\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\2022\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\2022\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\2023\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\2023\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\2023\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\2023\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\2024\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\2024\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\2024\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\2024\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\andaman-&-nicobar-islands\2020\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\andaman-&-nicobar-islands\2020\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\andaman-&-nicobar-islands\2020\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\andaman-&-nicobar-islands\2021\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\andaman-&-nicobar-islands\2021\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\andaman-&-nicobar-islands\2021\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\andaman-&-nicobar-islands\2021\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\andaman-&-nicobar-islands\2022\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\andaman-&-nicobar-islands\2022\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\andaman-&-nicobar-islands\2022\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\andaman-&-nicobar-islands\2022\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\andaman-&-nicobar-islands\2023\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\andaman-&-nicobar-islands\2023\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\andaman-&-nicobar-islands\2023\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\andaman-&-nicobar-islands\2023\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\andaman-&-nicobar-islands\2024\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\andaman-&-nicobar-islands\2024\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\andaman-&-nicobar-islands\2024\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\andaman-&-nicobar-islands\2024\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\andhra-pradesh\2020\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\andhra-pradesh\2020\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\andhra-pradesh\2020\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\andhra-pradesh\2021\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\andhra-pradesh\2021\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\andhra-pradesh\2021\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\andhra-pradesh\2021\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\andhra-pradesh\2022\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\andhra-pradesh\2022\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\andhra-pradesh\2022\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\andhra-pradesh\2022\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\andhra-pradesh\2023\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\andhra-pradesh\2023\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\andhra-pradesh\2023\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\andhra-pradesh\2023\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\andhra-pradesh\2024\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\andhra-pradesh\2024\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\andhra-pradesh\2024\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\andhra-pradesh\2024\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\arunachal-pradesh\2020\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\arunachal-pradesh\2020\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\arunachal-pradesh\2020\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\arunachal-pradesh\2021\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\arunachal-pradesh\2021\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\arunachal-pradesh\2021\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\arunachal-pradesh\2021\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\arunachal-pradesh\2022\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\arunachal-pradesh\2022\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\arunachal-pradesh\2022\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\arunachal-pradesh\2022\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\arunachal-pradesh\2023\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\arunachal-pradesh\2023\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\arunachal-pradesh\2023\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\arunachal-pradesh\2023\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\arunachal-pradesh\2024\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\arunachal-pradesh\2024\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\arunachal-pradesh\2024\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\arunachal-pradesh\2024\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\assam\2020\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\assam\2020\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\assam\2020\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\assam\2021\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\assam\2021\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\assam\2021\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\assam\2021\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\assam\2022\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\assam\2022\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\assam\2022\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\assam\2022\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\assam\2023\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\assam\2023\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\assam\2023\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\assam\2023\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\assam\2024\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\assam\2024\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\assam\2024\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\assam\2024\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\bihar\2020\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\bihar\2020\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\bihar\2020\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\bihar\2021\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\bihar\2021\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\bihar\2021\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\bihar\2021\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\bihar\2022\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\bihar\2022\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\bihar\2022\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\bihar\2022\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\bihar\2023\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\bihar\2023\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\bihar\2023\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\bihar\2023\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\bihar\2024\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\bihar\2024\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\bihar\2024\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\bihar\2024\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\chandigarh\2020\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\chandigarh\2020\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\chandigarh\2020\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\chandigarh\2021\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\chandigarh\2021\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\chandigarh\2021\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\chandigarh\2021\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\chandigarh\2022\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\chandigarh\2022\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\chandigarh\2022\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\chandigarh\2022\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\chandigarh\2023\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\chandigarh\2023\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\chandigarh\2023\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\chandigarh\2023\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\chandigarh\2024\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\chandigarh\2024\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\chandigarh\2024\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\chandigarh\2024\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\chhattisgarh\2020\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\chhattisgarh\2020\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\chhattisgarh\2020\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\chhattisgarh\2021\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\chhattisgarh\2021\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\chhattisgarh\2021\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\chhattisgarh\2021\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\chhattisgarh\2022\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\chhattisgarh\2022\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\chhattisgarh\2022\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\chhattisgarh\2022\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\chhattisgarh\2023\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\chhattisgarh\2023\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\chhattisgarh\2023\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\chhattisgarh\2023\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\chhattisgarh\2024\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\chhattisgarh\2024\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\chhattisgarh\2024\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\chhattisgarh\2024\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2020\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2020\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2020\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2021\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2021\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2021\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2021\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2022\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2022\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2022\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2022\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2023\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2023\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2023\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2023\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2024\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2024\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2024\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2024\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\delhi\2020\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\delhi\2020\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\delhi\2020\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\delhi\2021\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\delhi\2021\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\delhi\2021\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\delhi\2021\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\delhi\2022\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\delhi\2022\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\delhi\2022\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\delhi\2022\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\delhi\2023\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\delhi\2023\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\delhi\2023\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\delhi\2023\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\delhi\2024\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\delhi\2024\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\delhi\2024\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\delhi\2024\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\goa\2020\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\goa\2020\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\goa\2020\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\goa\2021\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\goa\2021\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\goa\2021\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\goa\2021\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\goa\2022\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\goa\2022\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\goa\2022\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\goa\2022\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\goa\2023\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\goa\2023\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\goa\2023\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\goa\2023\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\goa\2024\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\goa\2024\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\goa\2024\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\goa\2024\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\gujarat\2020\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\gujarat\2020\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\gujarat\2020\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\gujarat\2021\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\gujarat\2021\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\gujarat\2021\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\gujarat\2021\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\gujarat\2022\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\gujarat\2022\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\gujarat\2022\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\gujarat\2022\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\gujarat\2023\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\gujarat\2023\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\gujarat\2023\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\gujarat\2023\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\gujarat\2024\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\gujarat\2024\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\gujarat\2024\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\gujarat\2024\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\haryana\2020\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\haryana\2020\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\haryana\2020\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\haryana\2021\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\haryana\2021\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\haryana\2021\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\haryana\2021\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\haryana\2022\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\haryana\2022\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\haryana\2022\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\haryana\2022\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\haryana\2023\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\haryana\2023\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\haryana\2023\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\haryana\2023\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\haryana\2024\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\haryana\2024\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\haryana\2024\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\haryana\2024\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\himachal-pradesh\2020\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\himachal-pradesh\2020\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\himachal-pradesh\2020\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\himachal-pradesh\2021\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\himachal-pradesh\2021\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\himachal-pradesh\2021\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\himachal-pradesh\2021\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\himachal-pradesh\2022\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\himachal-pradesh\2022\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\himachal-pradesh\2022\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\himachal-pradesh\2022\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\himachal-pradesh\2023\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\himachal-pradesh\2023\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\himachal-pradesh\2023\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\himachal-pradesh\2023\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\himachal-pradesh\2024\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\himachal-pradesh\2024\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\himachal-pradesh\2024\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\himachal-pradesh\2024\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\jammu-&-kashmir\2020\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\jammu-&-kashmir\2020\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\jammu-&-kashmir\2020\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\jammu-&-kashmir\2021\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\jammu-&-kashmir\2021\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\jammu-&-kashmir\2021\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\jammu-&-kashmir\2021\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\jammu-&-kashmir\2022\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\jammu-&-kashmir\2022\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\jammu-&-kashmir\2022\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\jammu-&-kashmir\2022\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\jammu-&-kashmir\2023\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\jammu-&-kashmir\2023\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\jammu-&-kashmir\2023\3.json
# Successfully inserted data from '3.json'.
# ...
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\telangana\2021\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\telangana\2022\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\telangana\2022\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\telangana\2022\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\telangana\2022\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\telangana\2023\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\telangana\2023\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\telangana\2023\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\telangana\2023\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\telangana\2024\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\telangana\2024\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\telangana\2024\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\telangana\2024\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\tripura\2020\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\tripura\2020\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\tripura\2020\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\tripura\2021\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\tripura\2021\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\tripura\2021\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\tripura\2021\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\tripura\2022\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\tripura\2022\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\tripura\2022\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\tripura\2022\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\tripura\2023\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\tripura\2023\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\tripura\2023\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\tripura\2023\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\tripura\2024\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\tripura\2024\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\tripura\2024\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\tripura\2024\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\uttar-pradesh\2020\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\uttar-pradesh\2020\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\uttar-pradesh\2020\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\uttar-pradesh\2021\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\uttar-pradesh\2021\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\uttar-pradesh\2021\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\uttar-pradesh\2021\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\uttar-pradesh\2022\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\uttar-pradesh\2022\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\uttar-pradesh\2022\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\uttar-pradesh\2022\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\uttar-pradesh\2023\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\uttar-pradesh\2023\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\uttar-pradesh\2023\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\uttar-pradesh\2023\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\uttar-pradesh\2024\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\uttar-pradesh\2024\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\uttar-pradesh\2024\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\uttar-pradesh\2024\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\uttarakhand\2020\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\uttarakhand\2020\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\uttarakhand\2020\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\uttarakhand\2021\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\uttarakhand\2021\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\uttarakhand\2021\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\uttarakhand\2021\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\uttarakhand\2022\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\uttarakhand\2022\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\uttarakhand\2022\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\uttarakhand\2022\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\uttarakhand\2023\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\uttarakhand\2023\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\uttarakhand\2023\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\uttarakhand\2023\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\uttarakhand\2024\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\uttarakhand\2024\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\uttarakhand\2024\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\uttarakhand\2024\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\west-bengal\2020\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\west-bengal\2020\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\west-bengal\2020\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\west-bengal\2021\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\west-bengal\2021\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\west-bengal\2021\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\west-bengal\2021\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\west-bengal\2022\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\west-bengal\2022\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\west-bengal\2022\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\west-bengal\2022\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\west-bengal\2023\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\west-bengal\2023\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\west-bengal\2023\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\west-bengal\2023\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\west-bengal\2024\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\west-bengal\2024\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\west-bengal\2024\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\insurance\country\india\state\west-bengal\2024\4.json
# Successfully inserted data from '4.json'.
#
# Verifying data from all files...
#
# Transactions Table (first 5 rows):
# (1, 'Insurance', 1585679400000, 1593282600000, 1692610792790, '2.json')
# (2, 'Insurance', 1593541800000, 1601231400000, 1692610844644, '3.json')
# (3, 'Insurance', 1601490600000, 1609093800000, 1692610897678, '4.json')
# (4, 'Insurance', 1609439400000, 1616869800000, 1692610949539, '1.json')
# (5, 'Insurance', 1617215400000, 1624818600000, 1692611001440, '2.json')
#
# PaymentInstruments Table (first 5 rows):
# (1, 1, 'TOTAL', 185348, 33732166.0)
# (2, 2, 'TOTAL', 354284, 89495076.0)
# (3, 3, 'TOTAL', 248626, 170979933.0)
# (4, 4, 'TOTAL', 318119, 206307024.0)
# (5, 5, 'TOTAL', 363989, 295066678.0)
#
# Transactions per source file:
# ('1.json', 1036)
# ('2.json', 1288)
# ('3.json', 1295)
# ('4.json', 1288)

# %%
json_root_dir = "C:\\Users\\mukta\\OneDrive\\Desktop\\Phonepay\\pulse\\data\\aggregated\\transaction\\country\\india"


db_file_path = "ag_transaction_data.db" #filename to reflect multiple files

def setup_database(db_path):
    """Sets up the SQLite database tables."""
    conn = None
    try:
        conn = sqlite3.connect(db_path)
        cursor = conn.cursor()

        # 1. Create the Transactions table
        cursor.execute('''
            CREATE TABLE IF NOT EXISTS Transactions (
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                name TEXT,
                from_timestamp INTEGER,
                to_timestamp INTEGER,
                response_timestamp INTEGER,
                source_file TEXT -- Add a column to track which file this data came from
            )
        ''')

        # 2. Create the PaymentInstruments table
        cursor.execute('''
            CREATE TABLE IF NOT EXISTS PaymentInstruments (
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                transaction_id INTEGER,
                type TEXT,
                count INTEGER,
                amount REAL,
                FOREIGN KEY (transaction_id) REFERENCES Transactions(id)
            )
        ''')
        conn.commit()
        print("Database tables created/ensured.")
    except sqlite3.Error as e:
        print(f"Error setting up database: {e}")
    finally:
        if conn:
            conn.close()

def insert_json_data(json_data, source_filename, db_path):
    """
    Inserts data from a single parsed JSON object into the SQLite database.
    """
    conn = None
    try:
        conn = sqlite3.connect(db_path)
        cursor = conn.cursor()

        # Extract top-level data
        success = json_data.get("success")
        code = json_data.get("code")
        response_timestamp = json_data.get("responseTimestamp")
        main_data = json_data.get("data", {})
        from_ts = main_data.get("from")
        to_ts = main_data.get("to")
        transaction_data_list = main_data.get("transactionData", [])

        # Insert into Transactions table
        if transaction_data_list:
            for transaction_item in transaction_data_list:
                transaction_name = transaction_item.get("name")

                cursor.execute('''
                    INSERT INTO Transactions (name, from_timestamp, to_timestamp, response_timestamp, source_file)
                    VALUES (?, ?, ?, ?, ?)
                ''', (transaction_name, from_ts, to_ts, response_timestamp, source_filename))
                transaction_id = cursor.lastrowid # Get the ID of the newly inserted row

                # Insert into PaymentInstruments table
                payment_instruments = transaction_item.get("paymentInstruments", [])
                for pi in payment_instruments:
                    pi_type = pi.get("type")
                    pi_count = pi.get("count")
                    pi_amount = pi.get("amount")

                    cursor.execute('''
                        INSERT INTO PaymentInstruments (transaction_id, type, count, amount)
                        VALUES (?, ?, ?, ?)
                    ''', (transaction_id, pi_type, pi_count, pi_amount))
            conn.commit()
            print(f"Successfully inserted data from '{source_filename}'.")
        else:
            print(f"No 'transactionData' found in '{source_filename}'. Skipping data insertion.")

    except sqlite3.Error as e:
        print(f"Error inserting data from '{source_filename}': {e}")
        if conn:
            conn.rollback() # Rollback changes for this file if an error occurs
    finally:
        if conn:
            conn.close()

def load_folder_of_jsons_to_sqlite(folder_path, db_path):
    """
    Loads all JSON files from a specified folder and its subfolders into a SQLite database.
    """
    setup_database(db_path) # Ensure tables are set up before starting insertions

    json_files = glob.glob(os.path.join(folder_path, '**', '*.json'), recursive=True)

    if not json_files:
        print(f"No JSON files found in '{folder_path}' or its subdirectories.")
        return

    print(f"Found {len(json_files)} JSON files. Starting insertion...")
    for json_file in json_files:
        print(f"Processing: {json_file}")
        try:
            with open(json_file, 'r', encoding='utf-8') as f:
                data = json.load(f)
            # Pass the basename of the file for tracking
            insert_json_data(data, os.path.basename(json_file), db_path)
        except FileNotFoundError:
            print(f"Error: JSON file not found (should not happen here): {json_file}")
        except json.JSONDecodeError:
            print(f"Error: Could not decode JSON from {json_file}. Skipping.")
        except PermissionError:
            print(f"Permission denied for file: {json_file}. Skipping.")


# --- Main Execution ---
if __name__ == "__main__":
   
    # The glob pattern will find all .json files recursively from json_root_dir.

    load_folder_of_jsons_to_sqlite(json_root_dir, db_file_path)

    #Verify data
    print("\nVerifying data from all files...")
    conn = sqlite3.connect(db_file_path)
    cursor = conn.cursor()

    cursor.execute("SELECT * FROM Transactions LIMIT 5") # Limit to 5 rows for brevity
    print("\nTransactions Table (first 5 rows):")
    for row in cursor.fetchall():
        print(row)

    cursor.execute("SELECT * FROM PaymentInstruments LIMIT 5") # Limit to 5 rows for brevity
    print("\nPaymentInstruments Table (first 5 rows):")
    for row in cursor.fetchall():
        print(row)

    # Example: How many transactions from each file?
    cursor.execute("SELECT source_file, COUNT(*) FROM Transactions GROUP BY source_file")
    print("\nTransactions per source file:")
    for row in cursor.fetchall():
        print(row)


    conn.close()
# Out:
# Database tables created/ensured.
# Found 1036 JSON files. Starting insertion...
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\2018\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\2018\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\2018\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\2018\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\2019\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\2019\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\2019\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\2019\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\2020\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\2020\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\2020\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\2020\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\2021\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\2021\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\2021\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\2021\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\2022\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\2022\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\2022\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\2022\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\2023\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\2023\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\2023\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\2023\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\2024\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\2024\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\2024\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\2024\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andaman-&-nicobar-islands\2018\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andaman-&-nicobar-islands\2018\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andaman-&-nicobar-islands\2018\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andaman-&-nicobar-islands\2018\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andaman-&-nicobar-islands\2019\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andaman-&-nicobar-islands\2019\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andaman-&-nicobar-islands\2019\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andaman-&-nicobar-islands\2019\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andaman-&-nicobar-islands\2020\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andaman-&-nicobar-islands\2020\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andaman-&-nicobar-islands\2020\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andaman-&-nicobar-islands\2020\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andaman-&-nicobar-islands\2021\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andaman-&-nicobar-islands\2021\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andaman-&-nicobar-islands\2021\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andaman-&-nicobar-islands\2021\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andaman-&-nicobar-islands\2022\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andaman-&-nicobar-islands\2022\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andaman-&-nicobar-islands\2022\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andaman-&-nicobar-islands\2022\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andaman-&-nicobar-islands\2023\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andaman-&-nicobar-islands\2023\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andaman-&-nicobar-islands\2023\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andaman-&-nicobar-islands\2023\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andaman-&-nicobar-islands\2024\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andaman-&-nicobar-islands\2024\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andaman-&-nicobar-islands\2024\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andaman-&-nicobar-islands\2024\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andhra-pradesh\2018\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andhra-pradesh\2018\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andhra-pradesh\2018\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andhra-pradesh\2018\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andhra-pradesh\2019\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andhra-pradesh\2019\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andhra-pradesh\2019\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andhra-pradesh\2019\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andhra-pradesh\2020\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andhra-pradesh\2020\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andhra-pradesh\2020\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andhra-pradesh\2020\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andhra-pradesh\2021\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andhra-pradesh\2021\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andhra-pradesh\2021\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andhra-pradesh\2021\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andhra-pradesh\2022\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andhra-pradesh\2022\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andhra-pradesh\2022\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andhra-pradesh\2022\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andhra-pradesh\2023\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andhra-pradesh\2023\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andhra-pradesh\2023\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andhra-pradesh\2023\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andhra-pradesh\2024\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andhra-pradesh\2024\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andhra-pradesh\2024\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\andhra-pradesh\2024\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\arunachal-pradesh\2018\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\arunachal-pradesh\2018\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\arunachal-pradesh\2018\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\arunachal-pradesh\2018\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\arunachal-pradesh\2019\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\arunachal-pradesh\2019\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\arunachal-pradesh\2019\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\arunachal-pradesh\2019\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\arunachal-pradesh\2020\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\arunachal-pradesh\2020\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\arunachal-pradesh\2020\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\arunachal-pradesh\2020\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\arunachal-pradesh\2021\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\arunachal-pradesh\2021\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\arunachal-pradesh\2021\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\arunachal-pradesh\2021\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\arunachal-pradesh\2022\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\arunachal-pradesh\2022\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\arunachal-pradesh\2022\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\arunachal-pradesh\2022\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\arunachal-pradesh\2023\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\arunachal-pradesh\2023\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\arunachal-pradesh\2023\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\arunachal-pradesh\2023\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\arunachal-pradesh\2024\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\arunachal-pradesh\2024\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\arunachal-pradesh\2024\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\arunachal-pradesh\2024\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\assam\2018\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\assam\2018\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\assam\2018\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\assam\2018\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\assam\2019\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\assam\2019\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\assam\2019\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\assam\2019\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\assam\2020\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\assam\2020\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\assam\2020\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\assam\2020\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\assam\2021\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\assam\2021\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\assam\2021\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\assam\2021\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\assam\2022\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\assam\2022\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\assam\2022\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\assam\2022\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\assam\2023\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\assam\2023\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\assam\2023\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\assam\2023\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\assam\2024\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\assam\2024\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\assam\2024\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\assam\2024\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\bihar\2018\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\bihar\2018\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\bihar\2018\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\bihar\2018\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\bihar\2019\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\bihar\2019\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\bihar\2019\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\bihar\2019\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\bihar\2020\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\bihar\2020\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\bihar\2020\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\bihar\2020\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\bihar\2021\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\bihar\2021\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\bihar\2021\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\bihar\2021\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\bihar\2022\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\bihar\2022\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\bihar\2022\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\bihar\2022\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\bihar\2023\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\bihar\2023\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\bihar\2023\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\bihar\2023\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\bihar\2024\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\bihar\2024\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\bihar\2024\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\bihar\2024\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chandigarh\2018\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chandigarh\2018\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chandigarh\2018\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chandigarh\2018\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chandigarh\2019\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chandigarh\2019\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chandigarh\2019\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chandigarh\2019\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chandigarh\2020\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chandigarh\2020\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chandigarh\2020\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chandigarh\2020\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chandigarh\2021\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chandigarh\2021\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chandigarh\2021\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chandigarh\2021\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chandigarh\2022\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chandigarh\2022\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chandigarh\2022\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chandigarh\2022\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chandigarh\2023\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chandigarh\2023\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chandigarh\2023\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chandigarh\2023\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chandigarh\2024\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chandigarh\2024\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chandigarh\2024\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chandigarh\2024\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chhattisgarh\2018\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chhattisgarh\2018\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chhattisgarh\2018\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chhattisgarh\2018\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chhattisgarh\2019\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chhattisgarh\2019\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chhattisgarh\2019\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chhattisgarh\2019\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chhattisgarh\2020\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chhattisgarh\2020\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chhattisgarh\2020\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chhattisgarh\2020\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chhattisgarh\2021\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chhattisgarh\2021\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chhattisgarh\2021\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chhattisgarh\2021\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chhattisgarh\2022\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chhattisgarh\2022\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chhattisgarh\2022\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chhattisgarh\2022\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chhattisgarh\2023\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chhattisgarh\2023\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chhattisgarh\2023\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chhattisgarh\2023\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chhattisgarh\2024\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chhattisgarh\2024\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chhattisgarh\2024\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\chhattisgarh\2024\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2018\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2018\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2018\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2018\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2019\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2019\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2019\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2019\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2020\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2020\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2020\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2020\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2021\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2021\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2021\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2021\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2022\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2022\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2022\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2022\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2023\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2023\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2023\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2023\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2024\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2024\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2024\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\dadra-&-nagar-haveli-&-daman-&-diu\2024\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\delhi\2018\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\delhi\2018\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\delhi\2018\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\delhi\2018\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\delhi\2019\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\delhi\2019\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\delhi\2019\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\delhi\2019\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\delhi\2020\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\delhi\2020\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\delhi\2020\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\delhi\2020\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\delhi\2021\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\delhi\2021\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\delhi\2021\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\delhi\2021\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\delhi\2022\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\delhi\2022\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\delhi\2022\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\delhi\2022\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\delhi\2023\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\delhi\2023\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\delhi\2023\3.json
# Successfully inserted data from '3.json'.
# ...
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\tripura\2024\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\tripura\2024\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\tripura\2024\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttar-pradesh\2018\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttar-pradesh\2018\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttar-pradesh\2018\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttar-pradesh\2018\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttar-pradesh\2019\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttar-pradesh\2019\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttar-pradesh\2019\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttar-pradesh\2019\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttar-pradesh\2020\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttar-pradesh\2020\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttar-pradesh\2020\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttar-pradesh\2020\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttar-pradesh\2021\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttar-pradesh\2021\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttar-pradesh\2021\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttar-pradesh\2021\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttar-pradesh\2022\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttar-pradesh\2022\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttar-pradesh\2022\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttar-pradesh\2022\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttar-pradesh\2023\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttar-pradesh\2023\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttar-pradesh\2023\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttar-pradesh\2023\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttar-pradesh\2024\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttar-pradesh\2024\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttar-pradesh\2024\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttar-pradesh\2024\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttarakhand\2018\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttarakhand\2018\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttarakhand\2018\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttarakhand\2018\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttarakhand\2019\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttarakhand\2019\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttarakhand\2019\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttarakhand\2019\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttarakhand\2020\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttarakhand\2020\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttarakhand\2020\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttarakhand\2020\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttarakhand\2021\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttarakhand\2021\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttarakhand\2021\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttarakhand\2021\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttarakhand\2022\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttarakhand\2022\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttarakhand\2022\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttarakhand\2022\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttarakhand\2023\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttarakhand\2023\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttarakhand\2023\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttarakhand\2023\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttarakhand\2024\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttarakhand\2024\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttarakhand\2024\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\uttarakhand\2024\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\west-bengal\2018\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\west-bengal\2018\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\west-bengal\2018\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\west-bengal\2018\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\west-bengal\2019\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\west-bengal\2019\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\west-bengal\2019\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\west-bengal\2019\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\west-bengal\2020\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\west-bengal\2020\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\west-bengal\2020\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\west-bengal\2020\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\west-bengal\2021\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\west-bengal\2021\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\west-bengal\2021\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\west-bengal\2021\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\west-bengal\2022\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\west-bengal\2022\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\west-bengal\2022\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\west-bengal\2022\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\west-bengal\2023\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\west-bengal\2023\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\west-bengal\2023\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\west-bengal\2023\4.json
# Successfully inserted data from '4.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\west-bengal\2024\1.json
# Successfully inserted data from '1.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\west-bengal\2024\2.json
# Successfully inserted data from '2.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\west-bengal\2024\3.json
# Successfully inserted data from '3.json'.
# Processing: C:\Users\mukta\OneDrive\Desktop\Phonepay\pulse\data\aggregated\transaction\country\india\state\west-bengal\2024\4.json
# Successfully inserted data from '4.json'.
#
# Verifying data from all files...
#
# Transactions Table (first 5 rows):
# (1, 'Recharge & bill payments', 1514745000000, 1522175400000, 1630346628866, '1.json')
# (2, 'Peer-to-peer payments', 1514745000000, 1522175400000, 1630346628866, '1.json')
# (3, 'Merchant payments', 1514745000000, 1522175400000, 1630346628866, '1.json')
# (4, 'Financial Services', 1514745000000, 1522175400000, 1630346628866, '1.json')
# (5, 'Others', 1514745000000, 1522175400000, 1630346628866, '1.json')
#
# PaymentInstruments Table (first 5 rows):
# (1, 1, 'TOTAL', 72550406, 14472713558.652578)
# (2, 2, 'TOTAL', 46982705, 147245883542.77402)
# (3, 3, 'TOTAL', 5368669, 4656678915.140091)
# (4, 4, 'TOTAL', 3762820, 815853105.1000277)
# (5, 5, 'TOTAL', 5761576, 4643217301.269438)
#
# Transactions per source file:
# ('1.json', 6460)
# ('2.json', 6470)
# ('3.json', 6465)
# ('4.json', 6475)

# %% [raw]
# ## Structure of aggregated user data json format

# %%
import json

with open("C:\\Users\\mukta\\OneDrive\\Desktop\\Phonepay\\pulse\\data\\aggregated\\user\\country\\india\\2018\\1.json", "r") as f:
    data = json.load(f)

print(json.dumps(data, indent=4))
# Out:
# {
#     "success": true,
#     "code": "SUCCESS",
#     "data": {
#         "aggregated": {
#             "registeredUsers": 46877867,
#             "appOpens": 0
#         },
#         "usersByDevice": [
#             {
#                 "brand": "Xiaomi",
#                 "count": 11926334,
#                 "percentage": 0.25441289809538475
#             },
#             {
#                 "brand": "Samsung",
#                 "count": 9609401,
#                 "percentage": 0.204988017052909
#             },
#             {
#                 "brand": "Vivo",
#                 "count": 5894293,
#                 "percentage": 0.1257372269092363
#             },
#             {
#                 "brand": "Oppo",
#                 "count": 4479351,
#                 "percentage": 0.09555364368434255
#             },
#             {
#                 "brand": "Realme",
#                 "count": 2376866,
#                 "percentage": 0.05070337351313361
#             },
#             {
#                 "brand": "Apple",
#                 "count": 1825153,
#                 "percentage": 0.03893421601285741
#             },
#             {
#                 "brand": "Motorola",
#                 "count": 1593250,
#                 "percentage": 0.033987254582210406
#             },
#             {
#                 "brand": "OnePlus",
#                 "count": 1536418,
#                 "percentage": 0.03277491273227086
#             },
#             {
#                 "brand": "Lenovo",
#                 "count": 1246507,
#                 "percentage": 0.026590522986039446
#             },
#             {
#                 "brand": "Huawei",
#                 "count": 808774,
#                 "percentage": 0.01725279010668297
#             },
#             {
#                 "brand": "Others",
#                 "count": 5581520,
#                 "percentage": 0.1190651443249327
#             }
#         ]
#     },
#     "responseTimestamp": 1630501482414
# }

# %%
import re # For regular expressions to extract year/month/day from path

json_root_dir = "C:\\Users\\mukta\\OneDrive\\Desktop\\Phonepay\\pulse\\data\\aggregated\\user\\country\\india" # <--- ADJUST THIS PATH

db_file_path = "ag_user_data.db" # <--- NEW DATABASE NAME

# --- Utility Function to Extract Date from Path ---
def extract_date_from_path(file_path):
    """
    Extracts year, month, and day from a file path using a common pattern like /YYYY/MM/DD.json
    Returns (year, month, day) or (None, None, None) if not found.
    """
   
    match = re.search(r'[\\/](\d{4})[\\/](\d{1,2})[\\/](\d{1,2})\.json$', file_path)
    if match:
        return int(match.group(1)), int(match.group(2)), int(match.group(3))
    
    # Fallback for paths like /YYYY/MM/some_id/filename.json if 1.json is just an ID
    match_ym = re.search(r'[\\/](\d{4})[\\/](\d{1,2})[\\/]', file_path)
    if match_ym:
        # If the filename itself is numeric, it might be the day
        day_match = re.search(r'[\\/](\d+)\.json$', file_path)
        day = int(day_match.group(1)) if day_match else None
        return int(match_ym.group(1)), int(match_ym.group(2)), day

    return None, None, None # Default if no pattern matches

# --- Database Setup Functions ---
def setup_database(db_path):
    """Sets up the SQLite database tables for aggregated user data."""
    conn = None
    try:
        conn = sqlite3.connect(db_path)
        cursor = conn.cursor()

        # 1. Create the AggregatedSnapshots table
        cursor.execute('''
            CREATE TABLE IF NOT EXISTS AggregatedSnapshots (
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                success INTEGER, -- SQLite uses 0 for False, 1 for True
                code TEXT,
                registeredUsers INTEGER,
                appOpens INTEGER,
                year INTEGER,
                month INTEGER,
                day INTEGER,
                source_file TEXT UNIQUE -- Assuming each JSON file represents a unique snapshot
            )
        ''')

        # 2. Create the UsersByDevice table
        cursor.execute('''
            CREATE TABLE IF NOT EXISTS UsersByDevice (
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                snapshot_id INTEGER,
                brand TEXT,
                count INTEGER,
                percentage REAL,
                FOREIGN KEY (snapshot_id) REFERENCES AggregatedSnapshots(id)
            )
        ''')
        conn.commit()
        print("Database tables created/ensured for aggregated user data.")
    except sqlite3.Error as e:
        print(f"Error setting up database: {e}")
    finally:
        if conn:
            conn.close()

# --- Data Insertion Function ---
def insert_aggregated_user_snapshot(json_data, source_full_path, db_path):
    """
    Inserts data from a single parsed aggregated user JSON object into the SQLite database.
    """
    conn = None
    source_filename = os.path.basename(source_full_path)
    
    # Extract year, month, day from the full file path
    year, month, day = extract_date_from_path(source_full_path)

    try:
        conn = sqlite3.connect(db_path)
        cursor = conn.cursor()

        # Extract data from the JSON object
        success = 1 if json_data.get("success") else 0 # Convert boolean to integer for SQLite
        code = json_data.get("code")
        
        aggregated_data = json_data.get("data", {}).get("aggregated", {})
        registered_users = aggregated_data.get("registeredUsers")
        app_opens = aggregated_data.get("appOpens")
        
        # Insert into AggregatedSnapshots table
        # Using INSERT OR IGNORE to prevent re-inserting the same snapshot if the script is run multiple times
        cursor.execute('''
            INSERT OR IGNORE INTO AggregatedSnapshots (
                success, code, registeredUsers, appOpens, year, month, day, source_file
            )
            VALUES (?, ?, ?, ?, ?, ?, ?, ?)
        ''', (
            success, code, registered_users, app_opens, year, month, day, source_filename
        ))

        # If the snapshot was actually inserted (not ignored), get its ID
        if cursor.rowcount > 0: # rowcount will be 1 if inserted, 0 if ignored (due to UNIQUE source_file)
            snapshot_id = cursor.lastrowid
            
            # Insert into UsersByDevice table
            users_by_device_list = json_data.get("data", {}).get("usersByDevice", [])
            for device_data in users_by_device_list:
                brand = device_data.get("brand")
                count = device_data.get("count")
                percentage = device_data.get("percentage")

                cursor.execute('''
                    INSERT INTO UsersByDevice (snapshot_id, brand, count, percentage)
                    VALUES (?, ?, ?, ?)
                ''', (snapshot_id, brand, count, percentage))
            conn.commit()
            print(f"Successfully inserted data for snapshot '{source_filename}'.")
        else:
            print(f"Snapshot '{source_filename}' already exists in database. Skipping insertion.")

    except sqlite3.Error as e:
        print(f"Error inserting data from '{source_filename}': {e}")
        if conn:
            conn.rollback()
    except Exception as e: # Catch other potential errors during parsing/accessing
        print(f"General error processing '{source_filename}': {e}")
    finally:
        if conn:
            conn.close()

# --- Main Loading Logic ---
def load_folder_of_user_jsons_to_sqlite(folder_path, db_path):
    """
    Loads all JSON files from a specified folder and its subfolders (recursively)
    into a SQLite database for aggregated user data.
    """
    setup_database(db_path) # Ensure tables are set up before starting insertions

    # Use glob to find all .json files in the folder and its subfolders
    json_files = glob.glob(os.path.join(folder_path, '**', '*.json'), recursive=True)

    if not json_files:
        print(f"No JSON files found in '{folder_path}' or its subdirectories.")
        return

    print(f"Found {len(json_files)} JSON files. Starting insertion...")
    for json_file in json_files:
        # print(f"Processing file: {json_file}") # Uncomment for more verbose output
        try:
            with open(json_file, 'r', encoding='utf-8') as f:
                data = json.load(f)
            insert_aggregated_user_snapshot(data, json_file, db_path) # Pass full path for date extraction
        except FileNotFoundError:
            print(f"Error: JSON file not found (should not happen here): {json_file}")
        except json.JSONDecodeError:
            print(f"Error: Could not decode JSON from {json_file}. Skipping.")
        except PermissionError:
            print(f"Permission denied for file: {json_file}. Skipping.")
        except Exception as e:
            print(f"An unexpected error occurred while processing {json_file}: {e}")


# --- Execution ---
if __name__ == "__main__":
   

    load_folder_of_user_jsons_to_sqlite(json_root_dir, db_file_path)

    # Optional: Verify data
    print("\n--- Verifying loaded data ---")
    conn = sqlite3.connect(db_file_path)
    cursor = conn.cursor()

    cursor.execute("SELECT id, registeredUsers, appOpens, year, month, day, source_file FROM AggregatedSnapshots LIMIT 5")
    print("\nAggregatedSnapshots Table (first 5 rows):")
    for row in cursor.fetchall():
        print(row)

    cursor.execute("SELECT snapshot_id, brand, count, percentage FROM UsersByDevice LIMIT 5")
    print("\nUsersByDevice Table (first 5 rows):")
    for row in cursor.fetchall():
        print(row)

    cursor.execute("SELECT source_file, COUNT(*) FROM AggregatedSnapshots GROUP BY source_file")
    print("\nSnapshots loaded per source file:")
    for row in cursor.fetchall():
        print(row)
    
    cursor.execute("SELECT year, month, COUNT(*) FROM AggregatedSnapshots GROUP BY year, month ORDER BY year, month")
    print("\nSnapshots per Year and Month:")
    for row in cursor.fetchall():
        print(row)

    conn.close()
# Out:
# Database tables created/ensured for aggregated user data.
# Found 1036 JSON files. Starting insertion...
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# ...
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
#
# --- Verifying loaded data ---
#
# AggregatedSnapshots Table (first 5 rows):
# (1, 46877867, 0, None, None, None, '1.json')
# (2, 63648311, 0, None, None, None, '2.json')
# (3, 80010952, 0, None, None, None, '3.json')
# (4, 102262055, 0, None, None, None, '4.json')
#
# UsersByDevice Table (first 5 rows):
# (1, 'Xiaomi', 11926334, 0.25441289809538475)
# (1, 'Samsung', 9609401, 0.204988017052909)
# (1, 'Vivo', 5894293, 0.1257372269092363)
# (1, 'Oppo', 4479351, 0.09555364368434255)
# (1, 'Realme', 2376866, 0.05070337351313361)
#
# Snapshots loaded per source file:
# ('1.json', 1)
# ('2.json', 1)
# ('3.json', 1)
# ('4.json', 1)
#
# Snapshots per Year and Month:
# (None, None, 4)

# %% [raw]
# ##structure of map insurace data in json format

# %%
import json

with open("C:\\Users\\mukta\\OneDrive\\Desktop\\Phonepay\\pulse\\data\\map\\insurance\\country\\india\\2020\\2.json", "r") as f:
    data = json.load(f)
print(json.dumps(data, indent=4))
# Out:
# {
#     "success": true,
#     "code": "SUCCESS",
#     "data": {
#         "meta": {
#             "dataLevel": "COUNTRY",
#             "gridLevel": 10,
#             "percentiles": {
#                 "10.0": 1,
#                 "20.0": 1,
#                 "40.0": 1,
#                 "80.0": 7,
#                 "90.0": 17,
#                 "99.5": 563,
#                 "50.0": 2,
#                 "30.0": 1,
#                 "60.0": 3
#             }
#         },
#         "data": {
#             "columns": [
#                 "lat",
#                 "lng",
#                 "metric",
#                 "label"
#             ],
#             "data": [
#                 [
#                     12.88117483333963,
#                     77.56767350389504,
#                     4720.0,
#                     "karnataka"
#                 ],
#                 [
#                     17.42819734031383,
#                     78.38991078921848,
#                     3186.0,
#                     "telangana"
#                 ],
#                 [
#                     12.967106608090903,
#                     77.47593338307468,
#                     2753.0,
#                     "karnataka"
#                 ],
#                 [
#                     17.340345100987456,
#                     78.48087750095107,
#                     2674.0,
#                     "telangana"
#                 ],
#                 [
#                     12.885550475871199,
#                     77.6593393814543,
#                     2408.0,
#                     "karnataka"
#                 ],
#                 [
#                     12.876763583242758,
#                     77.47593338307468,
#                     2191.0,
#                     "karnataka"
#                 ],
#                 [
#                     12.971546671428015,
#                     77.56767350389504,
#                     2179.0,
#                     "karnataka"
#                 ],
#                 [
#                     19.03954728015671,
#                     72.8220063622904,
#                     2074.0,
#                     "maharashtra"
#                 ],
#                 [
#                     19.130363332127423,
#                     72.81018874044202,
#                     1859.0,
#                     "maharashtra"
#                 ],
#                 [
#                     12.975950892481984,
#                     77.6593393814543,
#                     1842.0,
#                     "karnataka"
#                 ],
#                 [
#                     28.54443223525236,
#                     77.29223320023456,
#                     1801.0,
#                     "delhi"
#                 ],
#                 [
#                     19.140517535728964,
#                     72.9165266460554,
#                     1733.0,
#                     "maharashtra"
#                 ],
#                 [
#                     28.609747093289457,
#                     77.01614358689307,
#                     1700.0,
#                     "delhi"
#                 ],
#                 [
#                     17.424176987312077,
#                     78.298863666532,
#                     1643.0,
#                     "telangana"
#                 ],
#                 [
#                     28.61864223670125,
#                     77.10824443175821,
#                     1611.0,
#                     "delhi"
#                 ],
#                 [
#                     28.42622865974866,
#                     77.01614358689307,
#                     1548.0,
#                     "haryana"
#                 ],
#                 [
#                     18.57265394755691,
#                     73.75366953292578,
#                     1525.0,
#                     "maharashtra"
#                 ],
#                 [
#                     17.43351726702052,
#                     78.48087750095107,
#                     1417.0,
#                     "telangana"
#                 ],
#                 [
#                     19.1595152916031,
#                     73.09365094896565,
#                     1358.0,
#                     "maharashtra"
#                 ],
#                 [
#                     17.3350500364044,
#                     78.38991078921848,
#                     1303.0,
#                     "telangana"
#                 ],
#                 [
#                     28.535696085269937,
#                     77.20027453793233,
#                     1291.0,
#                     "delhi"
#                 ],
#                 [
#                     19.95737977609375,
#                     73.75366953292578,
#                     1228.0,
#                     "maharashtra"
#                 ],
#                 [
#                     19.831768086244026,
#                     75.34704796764395,
#                     1221.0,
#                     "maharashtra"
#                 ],
#                 [
#                     19.223464333209357,
#                     72.8220063622904,
#                     1211.0,
#                     "maharashtra"
#                 ],
#                 [
#                     18.488742456516075,
#                     73.84778739924586,
#                     1198.0,
#                     "maharashtra"
#                 ],
#                 [
#                     18.947622260768604,
#                     72.81018874044202,
#                     1129.0,
#                     "maharashtra"
#                 ],
#                 [
#                     14.609447551198032,
#                     77.56767350389504,
#                     1117.0,
#                     "andhra pradesh"
#                 ],
#                 [
#                     28.627466876833797,
#                     77.20027453793233,
#                     1096.0,
#                     "delhi"
#                 ],
#                 [
#                     18.48360989140176,
#                     73.75366953292578,
#                     1089.0,
#                     "maharashtra"
#                 ],
#                 [
#                     28.6362211020919,
#                     77.29223320023456,
#                     1014.0,
#                     "uttar pradesh"
#                 ],
#                 [
#                     17.677804630869137,
#                     83.25595326647776,
#                     992.0,
#                     "andhra pradesh"
#                 ],
#                 [
#                     28.51801291477175,
#                     77.01614358689307,
#                     976.0,
#                     "haryana"
#                 ],
#                 [
#                     19.14836903752075,
#                     72.99920129684928,
#                     948.0,
#                     "maharashtra"
#                 ],
#                 [
#                     18.43115082349066,
#                     73.84778739924586,
#                     929.0,
#                     "maharashtra"
#                 ],
#                 [
#                     22.65635755730425,
#                     75.81271993338781,
#                     917.0,
#                     "madhya pradesh"
#                 ],
#                 [
#                     19.05635270164346,
#                     72.99920129684928,
#                     901.0,
#                     "maharashtra"
#                 ],
#                 [
#                     19.04741281817796,
#                     72.90471363631887,
#                     891.0,
#                     "maharashtra"
#                 ],
#                 [
#                     28.553098214360272,
#                     77.38411971559434,
#                     863.0,
#                     "uttar pradesh"
#                 ],
#                 [
#                     13.061987915284304,
#                     77.56767350389504,
#                     860.0,
#                     "karnataka"
#                 ],
#                 [
#                     28.478313768922735,
#                     77.20027453793233,
#                     846.0,
#                     "delhi"
#                 ],
#                 [
#                     12.993792239613954,
#                     80.19308589963396,
#                     845.0,
#                     "tamil nadu"
#                 ],
#                 [
#                     12.79522011587815,
#                     77.6593393814543,
#                     823.0,
#                     "karnataka"
#                 ],
#                 [
#                     19.812341431261498,
#                     75.25373970206532,
#                     777.0,
#                     "maharashtra"
#                 ],
#                 [
#                     18.411438436958857,
#                     73.75366953292578,
#                     764.0,
#                     "maharashtra"
#                 ],
#                 [
#                     18.96546800834851,
#                     73.01100959779343,
#                     763.0,
#                     "maharashtra"
#                 ],
#                 [
#                     19.40746595283282,
#                     72.81018874044202,
#                     741.0,
#                     "maharashtra"
#                 ],
#                 [
#                     22.52194302908239,
#                     88.32878957469845,
#                     712.0,
#                     "west bengal"
#                 ],
#                 [
#                     28.710343996195732,
#                     77.10824443175821,
#                     710.0,
#                     "delhi"
#                 ],
#                 [
#                     18.97320963635477,
#                     73.09365094896565,
#                     703.0,
#                     "maharashtra"
#                 ],
#                 [
#                     16.425973325386096,
#                     80.63824129823794,
#                     681.0,
#                     "andhra pradesh"
#                 ],
#                 [
#                     12.792507357503204,
#                     77.56767350389504,
#                     664.0,
#                     "karnataka"
#                 ],
#                 [
#                     23.063157644463807,
#                     72.52639838396267,
#                     630.0,
#                     "gujarat"
#                 ],
#                 [
#                     22.977699522702377,
#                     72.52639838396267,
#                     628.0,
#                     "gujarat"
#                 ],
#                 [
#                     26.826946549833224,
#                     75.71970391561408,
#                     618.0,
#                     "rajasthan"
#                 ],
#                 [
#                     16.240221042277636,
#                     80.37143260200438,
#                     579.0,
#                     "andhra pradesh"
#                 ],
#                 [
#                     18.4969129824917,
#                     73.94186034276925,
#                     568.0,
#                     "maharashtra"
#                 ],
#                 [
#                     13.600661081633229,
#                     79.38597503411559,
#                     563.0,
#                     "andhra pradesh"
#                 ],
#                 [
#                     22.61795526890876,
#                     88.40645404103664,
#                     558.0,
#                     "west bengal"
#                 ],
#                 [
#                     23.165198558244192,
#                     77.38411971559434,
#                     553.0,
#                     "madhya pradesh"
#                 ],
#                 [
#                     28.45259299069557,
#                     77.29223320023456,
#                     550.0,
#                     "uttar pradesh"
#                 ],
#                 [
#                     22.617169548494953,
#                     88.32878957469845,
#                     548.0,
#                     "west bengal"
#                 ],
#                 [
#                     21.157370009316743,
#                     72.81018874044202,
#                     545.0,
#                     "gujarat"
#                 ],
#                 [
#                     16.941629797151826,
#                     81.7841702924854,
#                     543.0,
#                     "andhra pradesh"
#                 ],
#                 [
#                     23.63459262671674,
#                     86.42379234230407,
#                     536.0,
#                     "jharkhand"
#                 ],
#                 [
#                     22.426509235849327,
#                     88.32878957469845,
#                     533.0,
#                     "west bengal"
#                 ],
#                 [
#                     16.42198724353521,
#                     80.54940073446988,
#                     524.0,
#                     "andhra pradesh"
#                 ],
#                 [
#                     13.057519060792652,
#                     77.47593338307468,
#                     521.0,
#                     "karnataka"
#                 ],
#                 [
#                     28.529097868954217,
#                     77.10824443175821,
#                     518.0,
#                     "delhi"
#                 ],
#                 [
#                     19.24040707528128,
#                     72.99920129684928,
#                     516.0,
#                     "maharashtra"
#                 ],
#                 [
#                     17.636784404845532,
#                     75.90567529309948,
#                     510.0,
#                     "maharashtra"
#                 ],
#                 [
#                     16.958718231256984,
#                     82.2202950557603,
#                     501.0,
#                     "andhra pradesh"
#                 ],
#                 [
#                     16.518760368892952,
#                     80.63824129823794,
#                     493.0,
#                     "andhra pradesh"
#                 ],
#                 [
#                     17.247208447254227,
#                     78.48087750095107,
#                     492.0,
#                     "telangana"
#                 ],
#                 [
#                     17.43879091751983,
#                     78.57176312812575,
#                     491.0,
#                     "telangana"
#                 ],
#                 [
#                     19.16947629935535,
#                     73.18806182048023,
#                     487.0,
#                     "maharashtra"
#                 ],
#                 [
#                     28.644905002831063,
#                     77.38411971559434,
#                     478.0,
#                     "uttar pradesh"
#                 ],
#                 [
#                     22.981695394037313,
#                     72.62103033913469,
#                     474.0,
#                     "gujarat"
#                 ],
#                 [
#                     17.345594108779185,
#                     78.57176312812575,
#                     469.0,
#                     "telangana"
#                 ],
#                 [
#                     16.516759916613772,
#                     80.54940073446988,
#                     459.0,
#                     "andhra pradesh"
#                 ],
#                 [
#                     28.435086934533953,
#                     77.10824443175821,
#                     455.0,
#                     "delhi"
#                 ],
#                 [
#                     17.66307794275852,
#                     83.17025968313696,
#                     451.0,
#                     "andhra pradesh"
#                 ],
#                 [
#                     17.521379458452248,
#                     78.38991078921848,
#                     435.0,
#                     "telangana"
#                 ],
#                 [
#                     28.36070399624803,
#                     77.29223320023456,
#                     423.0,
#                     "haryana"
#                 ],
#                 [
#                     17.75140249139584,
#                     83.34153342076118,
#                     420.0,
#                     "andhra pradesh"
#                 ],
#                 [
#                     12.902755060691176,
#                     80.19308589963396,
#                     416.0,
#                     "tamil nadu"
#                 ],
#                 [
#                     22.522721320354577,
#                     88.40645404103664,
#                     405.0,
#                     "west bengal"
#                 ],
#                 [
#                     18.58193922298074,
#                     73.84778739924586,
#                     400.0,
#                     "maharashtra"
#                 ],
#                 [
#                     28.71918676507349,
#                     77.20027453793233,
#                     397.0,
#                     "delhi"
#                 ],
#                 [
#                     18.03652537927283,
#                     83.36291067534142,
#                     389.0,
#                     "andhra pradesh"
#                 ],
#                 [
#                     19.249366940290656,
#                     73.09365094896565,
#                     388.0,
#                     "maharashtra"
#                 ],
#                 [
#                     13.129096038778716,
#                     79.02495158966912,
#                     388.0,
#                     "andhra pradesh"
#                 ],
#                 [
#                     17.962745519395472,
#                     79.56596325253265,
#                     379.0,
#                     "telangana"
#                 ],
#                 [
#                     17.515988155882052,
#                     78.298863666532,
#                     377.0,
#                     "telangana"
#                 ],
#                 [
#                     26.916764160388965,
#                     75.71970391561408,
#                     375.0,
#                     "rajasthan"
#                 ],
#                 [
#                     14.407900725642897,
#                     78.76462279866286,
#                     373.0,
#                     "andhra pradesh"
#                 ],
#                 [
#                     12.291933650685834,
#                     76.5546031082873,
#                     368.0,
#                     "karnataka"
#                 ],
#                 [
#                     13.084898933250928,
#                     80.19308589963396,
#                     356.0,
#                     "tamil nadu"
#                 ],
#                 [
#                     19.9540755203403,
#                     73.6595075078703,
#                     352.0,
#                     "maharashtra"
#                 ],
#                 [
#                     25.587327268291588,
#                     85.11162636754604,
#                     346.0,
#                     "bihar"
#                 ],
#                 [
#                     18.66481324841541,
#                     73.75366953292578,
#                     339.0,
#                     "maharashtra"
#                 ],
#                 [
#                     17.32970885032058,
#                     78.298863666532,
#                     339.0,
#                     "telangana"
#                 ],
#                 [
#                     28.702548615635607,
#                     77.01614358689307,
#                     339.0,
#                     "delhi"
#                 ],
#                 [
#                     20.255224144790837,
#                     72.99920129684928,
#                     339.0,
#                     "dadra & nagar haveli & daman & diu"
#                 ],
#                 [
#                     19.8093999406791,
#                     75.19539343488115,
#                     338.0,
#                     "maharashtra"
#                 ],
#                 [
#                     17.960317178272298,
#                     79.47601330857533,
#                     338.0,
#                     "telangana"
#                 ],
#                 [
#                     20.191374363897697,
#                     85.7717907206235,
#                     337.0,
#                     "odisha"
#                 ],
#                 [
#                     22.748555660902664,
#                     75.81271993338781,
#                     331.0,
#                     "madhya pradesh"
#                 ],
#                 [
#                     28.342133515297938,
#                     77.01614358689307,
#                     331.0,
#                     "haryana"
#                 ],
#                 [
#                     17.74848293928915,
#                     83.25595326647776,
#                     329.0,
#                     "andhra pradesh"
#                 ],
#                 [
#                     20.28600477275361,
#                     85.7717907206235,
#                     327.0,
#                     "odisha"
#                 ],
#                 [
#                     15.28559480782935,
#                     75.07863573282911,
#                     322.0,
#                     "karnataka"
#                 ],
#                 [
#                     22.96431723967442,
#                     72.4435673953583,
#                     321.0,
#                     "gujarat"
#                 ],
#                 [
#                     30.84708163222606,
#                     75.81271993338781,
#                     320.0,
#                     "punjab"
#                 ],
#                 [
#                     19.31887214264564,
#                     72.81018874044202,
#                     316.0,
#                     "maharashtra"
#                 ],
#                 [
#                     19.237033445117355,
#                     72.90471363631887,
#                     310.0,
#                     "maharashtra"
#                 ],
#                 [
#                     17.746266276066347,
#                     83.18097756644471,
#                     309.0,
#                     "andhra pradesh"
#                 ],
#                 [
#                     18.567467356660735,
#                     73.68305211218862,
#                     307.0,
#                     "maharashtra"
#                 ],
#                 [
#                     12.899379589818619,
#                     80.10377213393234,
#                     307.0,
#                     "tamil nadu"
#                 ],
#                 [
#                     12.980319308684528,
#                     77.75093032135311,
#                     300.0,
#                     "karnataka"
#                 ],
#                 [
#                     14.390500097808879,
#                     79.92486689605576,
#                     297.0,
#                     "andhra pradesh"
#                 ],
#                 [
#                     18.420307954389617,
#                     73.94186034276925,
#                     292.0,
#                     "maharashtra"
#                 ],
#                 [
#                     26.741291739241483,
#                     83.34153342076118,
#                     288.0,
#                     "uttar pradesh"
#                 ],
#                 [
#                     22.521230252542086,
#                     88.25098567594014,
#                     281.0,
#                     "west bengal"
#                 ],
#                 [
#                     15.480863162511158,
#                     80.01436559032136,
#                     279.0,
#                     "andhra pradesh"
#                 ],
#                 [
#                     16.690972944911167,
#                     81.08098475426915,
#                     275.0,
#                     "andhra pradesh"
#                 ],
#                 [
#                     22.712488043235442,
#                     88.32878957469845,
#                     274.0,
#                     "west bengal"
#                 ],
#                 [
#                     18.405936006725064,
#                     79.11533670045316,
#                     270.0,
#                     "telangana"
#                 ],
#                 [
#                     12.9903946016709,
#                     80.10377213393234,
#                     262.0,
#                     "tamil nadu"
#                 ],
#                 [
#                     23.317398851220354,
#                     85.27742074284158,
#                     261.0,
#                     "jharkhand"
#                 ],
#                 [
#                     21.123281762593518,
#                     79.02495158966912,
#                     261.0,
#                     "maharashtra"
#                 ],
#                 [
#                     28.417300105612995,
#                     76.92397271060467,
#                     260.0,
#                     "haryana"
#                 ],
#                 [
#                     26.741807317878916,
#                     75.81271993338781,
#                     255.0,
#                     "rajasthan"
#                 ],
#                 [
#                     28.26984614498395,
#                     77.29223320023456,
#                     253.0,
#                     "haryana"
#                 ],
#                 [
#                     17.253082586430086,
#                     78.57176312812575,
#                     246.0,
#                     "telangana"
#                 ],
#                 [
#                     22.664675934970223,
#                     75.90567529309948,
#                     240.0,
#                     "madhya pradesh"
#                 ],
#                 [
#                     21.02917864962114,
#                     79.02495158966912,
#                     240.0,
#                     "maharashtra"
#                 ],
#                 [
#                     20.247000857746503,
#                     72.90471363631887,
#                     240.0,
#                     "gujarat"
#                 ],
#                 [
#                     26.834067306174983,
#                     75.81271993338781,
#                     238.0,
#                     "rajasthan"
#                 ],
#                 [
#                     14.750916022001459,
#                     78.48087750095107,
#                     237.0,
#                     "andhra pradesh"
#                 ],
#                 [
#                     14.344095812187943,
#                     77.69369480289957,
#                     235.0,
#                     "andhra pradesh"
#                 ],
#                 [
#                     28.475951640129278,
#                     77.38411971559434,
#                     233.0,
#                     "uttar pradesh"
#                 ],
#                 [
#                     28.469818982884075,
#                     77.47593338307468,
#                     230.0,
#                     "uttar pradesh"
#                 ],
#                 [
#                     21.151205766870916,
#                     72.71562738313551,
#                     228.0,
#                     "gujarat"
#                 ],
#                 [
#                     23.256973079835515,
#                     77.38411971559434,
#                     228.0,
#                     "madhya pradesh"
#                 ],
#                 [
#                     26.792464173670272,
#                     80.90418166118614,
#                     216.0,
#                     "uttar pradesh"
#                 ],
#                 [
#                     20.969398522258807,
#                     75.53349284323835,
#                     209.0,
#                     "maharashtra"
#                 ],
#                 [
#                     26.37963267955883,
#                     80.28230626291116,
#                     207.0,
#                     "uttar pradesh"
#                 ],
#                 [
#                     17.63509871649007,
#                     75.84758534101024,
#                     207.0,
#                     "maharashtra"
#                 ],
#                 [
#                     26.130330691696663,
#                     91.75874959926448,
#                     207.0,
#                     "assam"
#                 ],
#                 [
#                     14.449445640361425,
#                     79.92486689605576,
#                     204.0,
#                     "andhra pradesh"
#                 ],
#                 [
#                     13.081908498437233,
#                     80.10377213393234,
#                     204.0,
#                     "tamil nadu"
#                 ],
#                 [
#                     17.240789527858386,
#                     80.10377213393234,
#                     202.0,
#                     "telangana"
#                 ],
#                 [
#                     21.20259814859196,
#                     81.60898731024885,
#                     199.0,
#                     "chhattisgarh"
#                 ],
#                 [
#                     28.945803735890696,
#                     77.6593393814543,
#                     192.0,
#                     "uttar pradesh"
#                 ],
#                 [
#                     31.289533330613136,
#                     75.53349284323835,
#                     189.0,
#                     "punjab"
#                 ],
#                 [
#                     28.338082549876983,
#                     76.92397271060467,
#                     187.0,
#                     "haryana"
#                 ],
#                 [
#                     14.42594603398734,
#                     75.90567529309948,
#                     182.0,
#                     "karnataka"
#                 ],
#                 [
#                     25.58453581924052,
#                     85.02854284373612,
#                     180.0,
#                     "bihar"
#                 ],
#                 [
#                     10.974809344519883,
#                     76.92397271060467,
#                     180.0,
#                     "tamil nadu"
#                 ],
#                 [
#                     28.603029415877764,
#                     76.92397271060467,
#                     179.0,
#                     "delhi"
#                 ],
#                 [
#                     22.299006565533297,
#                     73.10545444454523,
#                     178.0,
#                     "gujarat"
#                 ],
#                 [
#                     22.211970871007832,
#                     70.73468873356975,
#                     177.0,
#                     "gujarat"
#                 ],
#                 [
#                     20.88302398438743,
#                     77.75093032135311,
#                     176.0,
#                     "maharashtra"
#                 ],
#                 [
#                     29.62330140577444,
#                     76.97006685839166,
#                     175.0,
#                     "haryana"
#                 ],
#                 [
#                     21.129149876733127,
#                     79.11533670045316,
#                     174.0,
#                     "maharashtra"
#                 ],
#                 [
#                     22.437815343845994,
#                     88.25098567594014,
#                     174.0,
#                     "west bengal"
#                 ],
#                 [
#                     15.760783713053279,
#                     78.02524660458907,
#                     173.0,
#                     "andhra pradesh"
#                 ],
#                 [
#                     26.244375056150123,
#                     72.99920129684928,
#                     171.0,
#                     "rajasthan"
#                 ],
#                 [
#                     19.138235809402836,
#                     73.22345574172566,
#                     170.0,
#                     "maharashtra"
#                 ],
#                 [
#                     12.889890547975334,
#                     77.75093032135311,
#                     170.0,
#                     "karnataka"
#                 ],
#                 [
#                     15.785535388295914,
#                     74.44670068318894,
#                     167.0,
#                     "karnataka"
#                 ],
#                 [
#                     26.886600757348713,
#                     80.91524342357481,
#                     164.0,
#                     "uttar pradesh"
#                 ],
#                 [
#                     27.132465520098304,
#                     77.93388462171518,
#                     161.0,
#                     "uttar pradesh"
#                 ],
#                 [
#                     23.17074638697988,
#                     77.47593338307468,
#                     160.0,
#                     "madhya pradesh"
#                 ],
#                 [
#                     23.15985379868078,
#                     79.92486689605576,
#                     160.0,
#                     "madhya pradesh"
#                 ],
#                 [
#                     26.699599898057386,
#                     88.40645404103664,
#                     158.0,
#                     "west bengal"
#                 ],
#                 [
#                     18.673105055530403,
#                     73.84778739924586,
#                     155.0,
#                     "maharashtra"
#                 ],
#                 [
#                     22.771000317073767,
#                     86.1802619071185,
#                     154.0,
#                     "jharkhand"
#                 ],
#                 [
#                     19.913113486906145,
#                     75.34704796764395,
#                     152.0,
#                     "maharashtra"
#                 ],
#                 [
#                     9.978546401631704,
#                     76.27687553446887,
#                     152.0,
#                     "kerala"
#                 ],
#                 [
#                     19.40173103603027,
#                     72.7510921157892,
#                     148.0,
#                     "maharashtra"
#                 ],
#                 [
#                     28.1338893481229,
#                     76.83173251222411,
#                     148.0,
#                     "rajasthan"
#                 ],
#                 [
#                     16.95290269395603,
#                     81.69663059424752,
#                     147.0,
#                     "andhra pradesh"
#                 ],
#                 [
#                     12.296515266473506,
#                     76.64704699668393,
#                     146.0,
#                     "karnataka"
#                 ],
#                 [
#                     16.681509022711115,
#                     74.22380201337529,
#                     145.0,
#                     "maharashtra"
#                 ],
#                 [
#                     18.65751557616655,
#                     73.6595075078703,
#                     145.0,
#                     "maharashtra"
#                 ],
#                 [
#                     17.526724200278853,
#                     78.48087750095107,
#                     143.0,
#                     "telangana"
#                 ],
#                 [
#                     13.311167195056031,
#                     77.10824443175821,
#                     142.0,
#                     "karnataka"
#                 ],
#                 [
#                     20.64898787948222,
#                     78.60582419663554,
#                     141.0,
#                     "maharashtra"
#                 ],
#                 [
#                     15.122981157671509,
#                     76.92397271060467,
#                     139.0,
#                     "karnataka"
#                 ],
#                 [
#                     12.826747678615373,
#                     74.82146925802986,
#                     139.0,
#                     "karnataka"
#                 ],
#                 [
#                     15.810912629732798,
#                     74.50531198636581,
#                     137.0,
#                     "karnataka"
#                 ],
#                 [
#                     13.055271093240794,
#                     77.38411971559434,
#                     137.0,
#                     "karnataka"
#                 ],
#                 [
#                     22.80799912309281,
#                     88.32878957469845,
#                     136.0,
#                     "west bengal"
#                 ],
#                 [
#                     19.131212737612973,
#                     77.29223320023456,
#                     136.0,
#                     "maharashtra"
#                 ],
#                 [
#                     17.649813302612955,
#                     83.0844531912709,
#                     135.0,
#                     "andhra pradesh"
#                 ],
#                 [
#                     21.071231793183937,
#                     72.81018874044202,
#                     134.0,
#                     "gujarat"
#                 ],
#                 [
#                     30.676092976183188,
#                     76.73942370312189,
#                     134.0,
#                     "chandigarh"
#                 ],
#                 [
#                     18.90054844323169,
#                     72.81018874044202,
#                     133.0,
#                     "maharashtra"
#                 ],
#                 [
#                     18.276935927907736,
#                     83.85260358369386,
#                     133.0,
#                     "andhra pradesh"
#                 ],
#                 [
#                     22.22441284680611,
#                     73.18806182048023,
#                     133.0,
#                     "gujarat"
#                 ],
#                 [
#                     20.718711262421184,
#                     78.58311809680983,
#                     132.0,
#                     "maharashtra"
#                 ],
#                 [
#                     28.35744980021479,
#                     77.21177329224568,
#                     132.0,
#                     "haryana"
#                 ],
#                 [
#                     26.78960588662428,
#                     80.82670638471264,
#                     129.0,
#                     "uttar pradesh"
#                 ],
#                 [
#                     22.75690830807823,
#                     75.90567529309948,
#                     129.0,
#                     "madhya pradesh"
#                 ],
#                 [
#                     18.64525325957641,
#                     78.07089850397327,
#                     129.0,
#                     "telangana"
#                 ],
#                 [
#                     19.870399736355875,
#                     73.75366953292578,
#                     129.0,
#                     "maharashtra"
#                 ],
#                 [
#                     22.307779153193678,
#                     73.18806182048023,
#                     129.0,
#                     "gujarat"
#                 ],
#                 [
#                     22.427289752366907,
#                     88.40645404103664,
#                     127.0,
#                     "west bengal"
#                 ],
#                 [
#                     29.338335322601736,
#                     76.93549787575917,
#                     127.0,
#                     "haryana"
#                 ],
#                 [
#                     18.36019542546238,
#                     76.5546031082873,
#                     126.0,
#                     "maharashtra"
#                 ],
#                 [
#                     15.83004146879625,
#                     78.02524660458907,
#                     125.0,
#                     "andhra pradesh"
#                 ],
#                 [
#                     14.906508634539597,
#                     77.96815442646259,
#                     124.0,
#                     "andhra pradesh"
#                 ],
#                 [
#                     12.811788082162447,
#                     80.19308589963396,
#                     124.0,
#                     "tamil nadu"
#                 ],
#                 [
#                     16.166312996726592,
#                     81.08098475426915,
#                     122.0,
#                     "andhra pradesh"
#                 ],
#                 [
#                     30.261239983385156,
#                     78.02524660458907,
#                     122.0,
#                     "uttarakhand"
#                 ],
#                 [
#                     26.798838759642525,
#                     80.99263265635967,
#                     118.0,
#                     "uttar pradesh"
#                 ],
#                 [
#                     20.287955978905906,
#                     85.85374175151827,
#                     118.0,
#                     "odisha"
#                 ],
#                 [
#                     25.111373801698537,
#                     75.81271993338781,
#                     116.0,
#                     "rajasthan"
#                 ],
#                 [
#                     26.470831900623978,
#                     80.28230626291116,
#                     115.0,
#                     "uttar pradesh"
#                 ],
#                 [
#                     28.13164512653229,
#                     76.76250729867353,
#                     115.0,
#                     "haryana"
#                 ],
#                 [
#                     29.124108134409806,
#                     75.71970391561408,
#                     114.0,
#                     "haryana"
#                 ],
#                 [
#                     19.046197031832776,
#                     74.69273537601603,
#                     114.0,
#                     "maharashtra"
#                 ],
#                 [
#                     12.24715641818645,
#                     76.5546031082873,
#                     114.0,
#                     "karnataka"
#                 ],
#                 [
#                     19.771040738503352,
#                     72.71562738313551,
#                     113.0,
#                     "maharashtra"
#                 ],
#                 [
#                     14.494177273008926,
#                     77.10824443175821,
#                     111.0,
#                     "andhra pradesh"
#                 ],
#                 [
#                     28.11010670365565,
#                     76.5546031082873,
#                     111.0,
#                     "haryana"
#                 ],
#                 [
#                     14.701021008133663,
#                     77.56767350389504,
#                     110.0,
#                     "andhra pradesh"
#                 ],
#                 [
#                     24.57642054435001,
#                     73.6595075078703,
#                     110.0,
#                     "rajasthan"
#                 ],
#                 [
#                     11.079697149391322,
#                     77.29223320023456,
#                     110.0,
#                     "tamil nadu"
#                 ],
#                 [
#                     13.22149760348138,
#                     79.03625439452695,
#                     110.0,
#                     "andhra pradesh"
#                 ],
#                 [
#                     13.795199063619561,
#                     77.47593338307468,
#                     109.0,
#                     "andhra pradesh"
#                 ],
#                 [
#                     17.241938291273293,
#                     78.38991078921848,
#                     109.0,
#                     "telangana"
#                 ],
#                 [
#                     20.339216635075292,
#                     72.90471363631887,
#                     109.0,
#                     "gujarat"
#                 ],
#                 [
#                     22.770514206086403,
#                     86.09882529240666,
#                     108.0,
#                     "jharkhand"
#                 ],
#                 [
#                     23.16870308543099,
#                     72.62103033913469,
#                     108.0,
#                     "gujarat"
#                 ],
#                 [
#                     23.125641968976492,
#                     75.73133421000526,
#                     107.0,
#                     "madhya pradesh"
#                 ],
#                 [
#                     15.36889368110647,
#                     74.97348050527863,
#                     107.0,
#                     "karnataka"
#                 ],
#                 [
#                     17.033064516087407,
#                     79.20563608018333,
#                     107.0,
#                     "telangana"
#                 ],
#                 [
#                     30.857392087323504,
#                     75.90567529309948,
#                     107.0,
#                     "punjab"
#                 ],
#                 [
#                     16.321216052363177,
#                     80.39369942290007,
#                     106.0,
#                     "andhra pradesh"
#                 ],
#                 [
#                     17.515310966050404,
#                     78.20773680889053,
#                     105.0,
#                     "telangana"
#                 ],
#                 [
#                     27.55694526343623,
#                     76.58927739382993,
#                     105.0,
#                     "rajasthan"
#                 ],
#                 [
#                     30.673703427246398,
#                     76.64704699668393,
#                     105.0,
#                     "punjab"
#                 ],
#                 [
#                     19.258273723452437,
#                     73.18806182048023,
#                     104.0,
#                     "maharashtra"
#                 ],
#                 [
#                     30.596403973832263,
#                     76.83173251222411,
#                     104.0,
#                     "haryana"
#                 ],
#                 [
#                     12.710309154178505,
#                     77.75093032135311,
#                     103.0,
#                     "karnataka"
#                 ],
#                 [
#                     21.15282178824858,
#                     72.65650836345877,
#                     102.0,
#                     "gujarat"
#                 ],
#                 [
#                     22.88154162339871,
#                     72.53822926103794,
#                     101.0,
#                     "gujarat"
#                 ],
#                 [
#                     15.456934352835168,
#                     74.97348050527863,
#                     100.0,
#                     "karnataka"
#                 ],
#                 [
#                     23.625440461005265,
#                     86.10901194459096,
#                     100.0,
#                     "jharkhand"
#                 ],
#                 [
#                     20.88460008454622,
#                     74.71614887015095,
#                     99.0,
#                     "maharashtra"
#                 ],
#                 [
#                     28.804216164451834,
#                     77.10824443175821,
#                     99.0,
#                     "delhi"
#                 ],
#                 [
#                     29.425015913004586,
#                     76.93549787575917,
#                     98.0,
#                     "haryana"
#                 ],
#                 [
#                     14.37090956674795,
#                     78.20773680889053,
#                     97.0,
#                     "andhra pradesh"
#                 ],
#                 [
#                     13.088284397596263,
#                     80.28230626291116,
#                     96.0,
#                     "tamil nadu"
#                 ],
#                 [
#                     12.787589579856801,
#                     77.47593338307468,
#                     96.0,
#                     "karnataka"
#                 ],
#                 [
#                     26.13129275556857,
#                     91.68092829400071,
#                     95.0,
#                     "assam"
#                 ],
#                 [
#                     13.880528133452158,
#                     75.53349284323835,
#                     94.0,
#                     "karnataka"
#                 ],
#                 [
#                     25.169388258997557,
#                     75.82434268562162,
#                     94.0,
#                     "rajasthan"
#                 ],
#                 [
#                     25.214697006835657,
#                     82.91250357978087,
#                     93.0,
#                     "uttar pradesh"
#                 ],
#                 [
#                     22.557893052275972,
#                     75.71970391561408,
#                     92.0,
#                     "madhya pradesh"
#                 ],
#                 [
#                     22.05726696912568,
#                     82.133281817645,
#                     92.0,
#                     "chhattisgarh"
#                 ],
#                 [
#                     13.133911794335983,
#                     79.11533670045316,
#                     92.0,
#                     "andhra pradesh"
#                 ],
#                 [
#                     18.64816807333381,
#                     78.11653089466729,
#                     91.0,
#                     "telangana"
#                 ],
#                 [
#                     28.381085961867207,
#                     77.47593338307468,
#                     90.0,
#                     "uttar pradesh"
#                 ],
#                 [
#                     18.72007983692337,
#                     79.47601330857533,
#                     90.0,
#                     "telangana"
#                 ],
#                 [
#                     18.0683866835591,
#                     82.65374554202978,
#                     90.0,
#                     "andhra pradesh"
#                 ],
#                 [
#                     25.438725403568014,
#                     81.7841702924854,
#                     89.0,
#                     "uttar pradesh"
#                 ],
#                 [
#                     17.251136437264524,
# ...
#                     1.0,
#                     "karnataka"
#                 ],
#                 [
#                     25.36411826110164,
#                     85.52517396986853,
#                     1.0,
#                     "bihar"
#                 ],
#                 [
#                     21.08682091003257,
#                     81.4553640434164,
#                     1.0,
#                     "chhattisgarh"
#                 ],
#                 [
#                     17.825483556145567,
#                     76.77404750161458,
#                     1.0,
#                     "maharashtra"
#                 ],
#                 [
#                     25.877179435274982,
#                     81.64186564422351,
#                     1.0,
#                     "uttar pradesh"
#                 ],
#                 [
#                     14.07305878255742,
#                     76.93549787575917,
#                     1.0,
#                     "karnataka"
#                 ],
#                 [
#                     13.438054543529807,
#                     76.9470219563662,
#                     1.0,
#                     "karnataka"
#                 ],
#                 [
#                     21.304106619112307,
#                     86.05805850036016,
#                     1.0,
#                     "odisha"
#                 ],
#                 [
#                     20.210620854288944,
#                     75.42864599079348,
#                     1.0,
#                     "maharashtra"
#                 ],
#                 [
#                     17.76645655162488,
#                     73.74190167904314,
#                     1.0,
#                     "maharashtra"
#                 ],
#                 [
#                     17.435653835965702,
#                     75.37036616117476,
#                     1.0,
#                     "maharashtra"
#                 ],
#                 [
#                     25.693574017568867,
#                     86.82705447302818,
#                     1.0,
#                     "bihar"
#                 ],
#                 [
#                     16.610103150576226,
#                     78.94579480734252,
#                     1.0,
#                     "telangana"
#                 ],
#                 [
#                     18.291485171510942,
#                     74.93841352452533,
#                     1.0,
#                     "maharashtra"
#                 ],
#                 [
#                     26.474492955316137,
#                     85.19458581621883,
#                     1.0,
#                     "bihar"
#                 ],
#                 [
#                     16.41264193040212,
#                     78.94579480734252,
#                     1.0,
#                     "telangana"
#                 ],
#                 [
#                     26.034476916171933,
#                     86.74666606823209,
#                     1.0,
#                     "bihar"
#                 ],
#                 [
#                     30.54964596353351,
#                     79.55472436212713,
#                     1.0,
#                     "uttarakhand"
#                 ],
#                 [
#                     22.869809388330406,
#                     86.89728541927103,
#                     1.0,
#                     "west bengal"
#                 ],
#                 [
#                     17.17509908792,
#                     77.29223320023456,
#                     1.0,
#                     "karnataka"
#                 ],
#                 [
#                     15.999956181917993,
#                     73.68305211218862,
#                     1.0,
#                     "maharashtra"
#                 ],
#                 [
#                     20.96568718134928,
#                     76.53148172302797,
#                     1.0,
#                     "maharashtra"
#                 ],
#                 [
#                     26.10404556753477,
#                     85.03893505421654,
#                     1.0,
#                     "bihar"
#                 ],
#                 [
#                     16.125773570331077,
#                     79.7007211421711,
#                     1.0,
#                     "andhra pradesh"
#                 ],
#                 [
#                     22.13218155235371,
#                     77.99099492887416,
#                     1.0,
#                     "madhya pradesh"
#                 ],
#                 [
#                     16.453480760948715,
#                     77.80813629685755,
#                     1.0,
#                     "telangana"
#                 ],
#                 [
#                     13.701293690616755,
#                     78.59447178674895,
#                     1.0,
#                     "andhra pradesh"
#                 ],
#                 [
#                     19.42763531947398,
#                     77.8767442334854,
#                     1.0,
#                     "maharashtra"
#                 ],
#                 [
#                     14.297446628027641,
#                     79.6333673564944,
#                     1.0,
#                     "andhra pradesh"
#                 ],
#                 [
#                     24.942701402105424,
#                     72.00533331875383,
#                     1.0,
#                     "rajasthan"
#                 ],
#                 [
#                     12.305017733582458,
#                     78.8212750396855,
#                     1.0,
#                     "tamil nadu"
#                 ],
#                 [
#                     21.001343284367376,
#                     70.67521344639957,
#                     1.0,
#                     "gujarat"
#                 ],
#                 [
#                     12.400585412170251,
#                     79.81286490135668,
#                     1.0,
#                     "tamil nadu"
#                 ],
#                 [
#                     27.789174528402544,
#                     94.06443519826824,
#                     1.0,
#                     "arunachal pradesh"
#                 ],
#                 [
#                     27.538679259966333,
#                     93.80956762247315,
#                     1.0,
#                     "arunachal pradesh"
#                 ],
#                 [
#                     27.483222604135975,
#                     95.16927515769227,
#                     1.0,
#                     "assam"
#                 ],
#                 [
#                     27.30786027693642,
#                     95.15884639768142,
#                     1.0,
#                     "assam"
#                 ],
#                 [
#                     27.226507016517296,
#                     94.06443519826824,
#                     1.0,
#                     "assam"
#                 ],
#                 [
#                     27.31830506888993,
#                     94.1360233596635,
#                     1.0,
#                     "assam"
#                 ],
#                 [
#                     27.182786228177065,
#                     95.36778437070875,
#                     1.0,
#                     "assam"
#                 ],
#                 [
#                     27.31050834181566,
#                     94.39249359604598,
#                     1.0,
#                     "assam"
#                 ],
#                 [
#                     27.44237853415025,
#                     94.30002108469532,
#                     1.0,
#                     "assam"
#                 ],
#                 [
#                     25.527170821327818,
#                     91.82695733365333,
#                     1.0,
#                     "meghalaya"
#                 ],
#                 [
#                     27.33835193474279,
#                     95.28411769257102,
#                     1.0,
#                     "assam"
#                 ],
#                 [
#                     27.535590669916928,
#                     94.68120862839055,
#                     1.0,
#                     "assam"
#                 ],
#                 [
#                     27.36374924474427,
#                     95.23188789578967,
#                     1.0,
#                     "assam"
#                 ],
#                 [
#                     27.321592819423618,
#                     94.4130648424604,
#                     1.0,
#                     "assam"
#                 ],
#                 [
#                     27.0045294752492,
#                     95.72471691017944,
#                     1.0,
#                     "arunachal pradesh"
#                 ],
#                 [
#                     27.44648165577013,
#                     94.88837363245398,
#                     1.0,
#                     "assam"
#                 ],
#                 [
#                     27.21486562795367,
#                     94.80541418378117,
#                     1.0,
#                     "assam"
#                 ],
#                 [
#                     27.2237350711629,
#                     94.88837363245398,
#                     1.0,
#                     "assam"
#                 ],
#                 [
#                     27.187818839107575,
#                     94.90913289889103,
#                     1.0,
#                     "assam"
#                 ],
#                 [
#                     27.175360409425767,
#                     94.92989991302532,
#                     1.0,
#                     "assam"
#                 ],
#                 [
#                     27.23107064468522,
#                     95.01304530579971,
#                     1.0,
#                     "assam"
#                 ],
#                 [
#                     26.443360087339354,
#                     92.89263422993362,
#                     1.0,
#                     "assam"
#                 ],
#                 [
#                     26.68371530189786,
#                     92.6536741749731,
#                     1.0,
#                     "assam"
#                 ],
#                 [
#                     27.715782134311915,
#                     94.88837363245398,
#                     1.0,
#                     "assam"
#                 ],
#                 [
#                     27.715416281276344,
#                     94.89875229677163,
#                     1.0,
#                     "assam"
#                 ],
#                 [
#                     27.596657513567234,
#                     95.56697858898481,
#                     1.0,
#                     "assam"
#                 ],
#                 [
#                     27.979844331191845,
#                     94.69154835367382,
#                     1.0,
#                     "arunachal pradesh"
#                 ],
#                 [
#                     27.484598096052633,
#                     95.44109235097051,
#                     1.0,
#                     "assam"
#                 ],
#                 [
#                     26.874651624309628,
#                     93.60658478673754,
#                     1.0,
#                     "assam"
#                 ],
#                 [
#                     26.812687432870852,
#                     93.72827687249308,
#                     1.0,
#                     "assam"
#                 ],
#                 [
#                     27.561976754788134,
#                     95.55647770672788,
#                     1.0,
#                     "assam"
#                 ],
#                 [
#                     27.490631421278977,
#                     95.28411769257102,
#                     1.0,
#                     "assam"
#                 ],
#                 [
#                     14.557401496812263,
#                     76.05659649414727,
#                     1.0,
#                     "karnataka"
#                 ],
#                 [
#                     18.329147255506925,
#                     76.83173251222411,
#                     1.0,
#                     "maharashtra"
#                 ],
#                 [
#                     8.295787405298803,
#                     77.30372297458574,
#                     1.0,
#                     "tamil nadu"
#                 ],
#                 [
#                     26.80806427768835,
#                     84.97655283433251,
#                     1.0,
#                     "bihar"
#                 ],
#                 [
#                     17.253111645709676,
#                     79.43100517234626,
#                     1.0,
#                     "telangana"
#                 ],
#                 [
#                     15.143828587677078,
#                     79.02495158966912,
#                     1.0,
#                     "andhra pradesh"
#                 ],
#                 [
#                     31.975071766980072,
#                     77.131258617636,
#                     1.0,
#                     "himachal pradesh"
#                 ],
#                 [
#                     23.465736833886705,
#                     86.94738799954307,
#                     1.0,
#                     "west bengal"
#                 ],
#                 [
#                     13.847977290463296,
#                     75.96374126459287,
#                     1.0,
#                     "karnataka"
#                 ],
#                 [
#                     23.63270849905189,
#                     87.66304500335588,
#                     1.0,
#                     "west bengal"
#                 ],
#                 [
#                     13.808057705221119,
#                     76.05659649414727,
#                     1.0,
#                     "karnataka"
#                 ],
#                 [
#                     13.999933294302755,
#                     75.28873693094538,
#                     1.0,
#                     "karnataka"
#                 ],
#                 [
#                     17.045607565117617,
#                     76.90091913220243,
#                     1.0,
#                     "karnataka"
#                 ],
#                 [
#                     19.808412023539912,
#                     84.78899066387379,
#                     1.0,
#                     "odisha"
#                 ],
#                 [
#                     12.217694090066212,
#                     78.61717532516249,
#                     1.0,
#                     "tamil nadu"
#                 ],
#                 [
#                     27.66640035101692,
#                     95.86176319180758,
#                     1.0,
#                     "arunachal pradesh"
#                 ],
#                 [
#                     26.869166412801707,
#                     95.58798599277755,
#                     1.0,
#                     "arunachal pradesh"
#                 ],
#                 [
#                     27.57506509474368,
#                     95.80901589396362,
#                     1.0,
#                     "assam"
#                 ],
#                 [
#                     27.305412459212274,
#                     95.81956164024935,
#                     1.0,
#                     "assam"
#                 ],
#                 [
#                     27.427716868449433,
#                     95.69313555556452,
#                     1.0,
#                     "assam"
#                 ],
#                 [
#                     27.539006412898257,
#                     96.10499584170577,
#                     1.0,
#                     "arunachal pradesh"
#                 ],
#                 [
#                     27.915737411985997,
#                     95.76685150360692,
#                     1.0,
#                     "assam"
#                 ],
#                 [
#                     27.683810453200547,
#                     95.72471691017944,
#                     1.0,
#                     "assam"
#                 ],
#                 [
#                     21.59907594226109,
#                     77.76237388528826,
#                     1.0,
#                     "madhya pradesh"
#                 ],
#                 [
#                     24.966101984063894,
#                     86.58549245102844,
#                     1.0,
#                     "bihar"
#                 ],
#                 [
#                     23.299003043154567,
#                     86.93737164765109,
#                     1.0,
#                     "west bengal"
#                 ],
#                 [
#                     22.491086304181525,
#                     92.98255591765016,
#                     1.0,
#                     "mizoram"
#                 ],
#                 [
#                     27.05284187246722,
#                     95.07548535560393,
#                     1.0,
#                     "assam"
#                 ]
#             ]
#         }
#     },
#     "responseTimestamp": 1692610792413
# }

# %%
json_root_dir = "C:\\Users\\mukta\\OneDrive\\Desktop\\Phonepay\\pulse\\data\\map\\insurance\\country\\india" # <--- ADJUST THIS PATH

# Define the path for your SQLite database file
db_file_path = "map_insurance_data.db" # <--- NEW DATABASE NAME

# --- Utility Function to Extract Date/Period from Path ---
def extract_period_from_path(file_path):
    """
    Extracts year and quarter/month/id from a file path using a common pattern like /YYYY/QQ.json or /YYYY/MM.json
    Returns (year, period) or (None, None) if not found.
    """
    # Regex to find /YYYY/NUMBER.json pattern
    match = re.search(r'[\\/](\d{4})[\\/](\d{1,2})\.json$', file_path)
    if match:
        return int(match.group(1)), int(match.group(2))
    
    # Fallback if filename is not a direct number, but the structure is /YYYY/MM/filename.json
    match_ym = re.search(r'[\\/](\d{4})[\\/](\d{1,2})[\\/]', file_path)
    if match_ym:
        # If the filename itself is numeric, it might be the day
        period_match = re.search(r'[\\/](\d+)\.json$', file_path)
        period = int(period_match.group(1)) if period_match else None
        return int(match_ym.group(1)), period

    return None, None # Default if no pattern matches

# --- Database Setup Functions ---
def setup_database(db_path):
    """Sets up the SQLite database tables for map insurance data."""
    conn = None
    try:
        conn = sqlite3.connect(db_path)
        cursor = conn.cursor()

        # 1. Create the MapInsuranceSnapshots table
        cursor.execute('''
            CREATE TABLE IF NOT EXISTS MapInsuranceSnapshots (
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                success INTEGER, -- SQLite uses 0 for False, 1 for True
                code TEXT,
                response_timestamp INTEGER,
                year INTEGER,
                quarter_or_month INTEGER,
                source_file TEXT UNIQUE
            )
        ''')

        # 2. Create the StateMetrics table
        cursor.execute('''
            CREATE TABLE IF NOT EXISTS StateMetrics (
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                snapshot_id INTEGER,
                state_name TEXT,
                total_count INTEGER,
                total_amount REAL,
                FOREIGN KEY (snapshot_id) REFERENCES MapInsuranceSnapshots(id)
            )
        ''')

        # 3. Create the DistrictMetrics table
        cursor.execute('''
            CREATE TABLE IF NOT EXISTS DistrictMetrics (
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                state_metric_id INTEGER,
                district_name TEXT,
                district_count INTEGER,
                district_amount REAL,
                FOREIGN KEY (state_metric_id) REFERENCES StateMetrics(id)
            )
        ''')
        conn.commit()
        print("Database tables created/ensured for map insurance data.")
    except sqlite3.Error as e:
        print(f"Error setting up database: {e}")
    finally:
        if conn:
            conn.close()

# --- Data Insertion Function ---
def insert_map_insurance_snapshot(json_data, source_full_path, db_path):
    """
    Inserts data from a single parsed map insurance JSON object into the SQLite database.
    """
    conn = None
    source_filename = os.path.basename(source_full_path)
    
    # Extract year and quarter/month from the full file path
    year, quarter_or_month = extract_period_from_path(source_full_path)

    try:
        conn = sqlite3.connect(db_path)
        cursor = conn.cursor()

        # Extract data from the JSON object
        success = 1 if json_data.get("success") else 0 # Convert boolean to integer
        code = json_data.get("code")
        response_timestamp = json_data.get("responseTimestamp")
        
        # Insert into MapInsuranceSnapshots table
        cursor.execute('''
            INSERT OR IGNORE INTO MapInsuranceSnapshots (
                success, code, response_timestamp, year, quarter_or_month, source_file
            )
            VALUES (?, ?, ?, ?, ?, ?)
        ''', (
            success, code, response_timestamp, year, quarter_or_month, source_filename
        ))

        # If the snapshot was actually inserted, get its ID
        if cursor.rowcount > 0:
            snapshot_id = cursor.lastrowid
            
            # Process hoverData (states/union territories)
            hover_data = json_data.get("data", {}).get("hoverData", {})
            for state_name, state_data in hover_data.items():
                state_metric = state_data.get("metric", {})
                state_count = state_metric.get("count")
                state_amount = state_metric.get("amount")

                cursor.execute('''
                    INSERT INTO StateMetrics (snapshot_id, state_name, total_count, total_amount)
                    VALUES (?, ?, ?, ?)
                ''', (snapshot_id, state_name, state_count, state_amount))
                state_metric_id = cursor.lastrowid # Get ID for linking districts

                # Process districtData for the current state
                district_data_list = state_data.get("districtData", [])
                for district_item in district_data_list:
                    district_name = district_item.get("name")
                    district_metric = district_item.get("metric", {})
                    district_count = district_metric.get("count")
                    district_amount = district_metric.get("amount")

                    cursor.execute('''
                        INSERT INTO DistrictMetrics (state_metric_id, district_name, district_count, district_amount)
                        VALUES (?, ?, ?, ?)
                    ''', (state_metric_id, district_name, district_count, district_amount))
            conn.commit()
            print(f"Successfully inserted data for snapshot '{source_filename}'.")
        else:
            print(f"Snapshot '{source_filename}' already exists in database. Skipping insertion.")

    except sqlite3.Error as e:
        print(f"Error inserting data from '{source_filename}': {e}")
        if conn:
            conn.rollback()
    except Exception as e: # Catch other potential errors during parsing/accessing
        print(f"General error processing '{source_filename}': {e}")
    finally:
        if conn:
            conn.close()

# --- Main Loading Logic ---
def load_folder_of_map_jsons_to_sqlite(folder_path, db_path):
    """
    Loads all JSON files from a specified folder and its subfolders (recursively)
    into a SQLite database for map insurance data.
    """
    setup_database(db_path) # Ensure tables are set up before starting insertions

    # Use glob to find all .json files in the folder and its subfolders
    json_files = glob.glob(os.path.join(folder_path, '**', '*.json'), recursive=True)

    if not json_files:
        print(f"No JSON files found in '{folder_path}' or its subdirectories.")
        return

    print(f"Found {len(json_files)} JSON files. Starting insertion...")
    for json_file in json_files:
        # print(f"Processing file: {json_file}") # Uncomment for more verbose output
        try:
            with open(json_file, 'r', encoding='utf-8') as f:
                data = json.load(f)
            insert_map_insurance_snapshot(data, json_file, db_path) # Pass full path for date extraction
        except FileNotFoundError:
            print(f"Error: JSON file not found (should not happen here): {json_file}")
        except json.JSONDecodeError:
            print(f"Error: Could not decode JSON from {json_file}. Skipping.")
        except PermissionError:
            print(f"Permission denied for file: {json_file}. Skipping.")
        except Exception as e:
            print(f"An unexpected error occurred while processing {json_file}: {e}")


# --- Execution ---
if __name__ == "__main__":
    

    load_folder_of_map_jsons_to_sqlite(json_root_dir, db_file_path)

    #Verify data
    print("\n--- Verifying loaded data ---")
    conn = sqlite3.connect(db_file_path)
    cursor = conn.cursor()

    cursor.execute("SELECT id, success, code, year, quarter_or_month, source_file FROM MapInsuranceSnapshots LIMIT 5")
    print("\nMapInsuranceSnapshots Table (first 5 rows):")
    for row in cursor.fetchall():
        print(row)

    cursor.execute("SELECT snapshot_id, state_name, total_count, total_amount FROM StateMetrics LIMIT 5")
    print("\nStateMetrics Table (first 5 rows):")
    for row in cursor.fetchall():
        print(row)

    cursor.execute("SELECT state_metric_id, district_name, district_count, district_amount FROM DistrictMetrics LIMIT 5")
    print("\nDistrictMetrics Table (first 5 rows):")
    for row in cursor.fetchall():
        print(row)

    cursor.execute("SELECT source_file, COUNT(*) FROM MapInsuranceSnapshots GROUP BY source_file")
    print("\nSnapshots loaded per source file:")
    for row in cursor.fetchall():
        print(row)
    
    cursor.execute("SELECT year, quarter_or_month, COUNT(*) FROM MapInsuranceSnapshots GROUP BY year, quarter_or_month ORDER BY year, quarter_or_month")
    print("\nSnapshots per Year and Quarter/Month:")
    for row in cursor.fetchall():
        print(row)

    conn.close()
# Out:
# Database tables created/ensured for map insurance data.
# Found 701 JSON files. Starting insertion...
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
#
# --- Verifying loaded data ---
#
# MapInsuranceSnapshots Table (first 5 rows):
# (1, 1, 'SUCCESS', 2020, 2, '2.json')
# (2, 1, 'SUCCESS', 2020, 3, '3.json')
# (3, 1, 'SUCCESS', 2020, 4, '4.json')
# (4, 1, 'SUCCESS', 2021, 1, '1.json')
#
# StateMetrics Table (first 5 rows):
#
# DistrictMetrics Table (first 5 rows):
#
# Snapshots loaded per source file:
# ('1.json', 1)
# ('2.json', 1)
# ('3.json', 1)
# ('4.json', 1)
#
# Snapshots per Year and Quarter/Month:
# (2020, 2, 1)
# (2020, 3, 1)
# (2020, 4, 1)
# (2021, 1, 1)

# %%
json_root_dir = "C:\\Users\\mukta\\OneDrive\\Desktop\\Phonepay\\pulse\\data\\map\\insurance\\hover\\country\\india" 

# Define the path for your SQLite database file
db_file_path = "map_hover_data.db" # <--- NEW DATABASE NAME

# --- Utility Function to Extract Date/Period from Path ---
def extract_period_from_path(file_path):
    """
    Extracts year and a generic period ID from a file path using a common pattern like /YYYY/PERIOD.json
    Returns (year, period) or (None, None) if not found.
    """
    # Regex to find /YYYY/NUMBER.json pattern
    match = re.search(r'[\\/](\d{4})[\\/](\d{1,3})\.json$', file_path)
    if match:
        return int(match.group(1)), int(match.group(2))
    
    return None, None # Default if no pattern matches

# --- Database Setup Functions ---
def setup_database(db_path):
    """Sets up the SQLite database tables for map hover data."""
    conn = None
    try:
        conn = sqlite3.connect(db_path)
        cursor = conn.cursor()

        # 1. Create the MapHoverSnapshots table
        cursor.execute('''
            CREATE TABLE IF NOT EXISTS MapHoverSnapshots (
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                success INTEGER, -- SQLite uses 0 for False, 1 for True
                code TEXT,
                year INTEGER,
                period_id INTEGER, -- Month, quarter, or arbitrary ID
                source_file TEXT UNIQUE
            )
        ''')

        # 2. Create the HoverDataEntries table
        cursor.execute('''
            CREATE TABLE IF NOT EXISTS HoverDataEntries (
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                snapshot_id INTEGER,
                region_name TEXT,
                metric_type TEXT,
                metric_count INTEGER,
                metric_amount REAL,
                FOREIGN KEY (snapshot_id) REFERENCES MapHoverSnapshots(id)
            )
        ''')

        conn.commit()
        print("Database tables created/ensured for map hover data.")
    except sqlite3.Error as e:
        print(f"Error setting up database: {e}")
    finally:
        if conn:
            conn.close()

# --- Data Insertion Function ---
def insert_map_hover_snapshot(json_data, source_full_path, db_path):
    """
    Inserts data from a single parsed map hover JSON object into the SQLite database.
    """
    conn = None
    source_filename = os.path.basename(source_full_path)
    
    # Extract year and period_id from the full file path
    year, period_id = extract_period_from_path(source_full_path)

    try:
        conn = sqlite3.connect(db_path)
        cursor = conn.cursor()

        # Extract data from the JSON object
        success = 1 if json_data.get("success") else 0 # Convert boolean to integer
        code = json_data.get("code")
        
        # Insert into MapHoverSnapshots table
        cursor.execute('''
            INSERT OR IGNORE INTO MapHoverSnapshots (
                success, code, year, period_id, source_file
            )
            VALUES (?, ?, ?, ?, ?)
        ''', (
            success, code, year, period_id, source_filename
        ))

        # If the snapshot was actually inserted, get its ID
        if cursor.rowcount > 0:
            snapshot_id = cursor.lastrowid
            
            # Process hoverdatalist
            hover_data_list = json_data.get("data", {}).get("hoverdatalist", [])
            for entry in hover_data_list:
                name = entry.get("name")
                metric = entry.get("metric", {})
                metric_type = metric.get("type")
                metric_count = metric.get("count")
                metric_amount = metric.get("amount")

                cursor.execute('''
                    INSERT INTO HoverDataEntries (snapshot_id, region_name, metric_type, metric_count, metric_amount)
                    VALUES (?, ?, ?, ?, ?)
                ''', (snapshot_id, name, metric_type, metric_count, metric_amount))
            conn.commit()
            print(f"Successfully inserted data for snapshot '{source_filename}'.")
        else:
            print(f"Snapshot '{source_filename}' already exists in database. Skipping insertion.")

    except sqlite3.Error as e:
        print(f"Error inserting data from '{source_filename}': {e}")
        if conn:
            conn.rollback()
    except Exception as e: # Catch other potential errors during parsing/accessing
        print(f"General error processing '{source_filename}': {e}")
    finally:
        if conn:
            conn.close()

# --- Main Loading Logic ---
def load_folder_of_map_hover_jsons_to_sqlite(folder_path, db_path):
    """
    Loads all JSON files from a specified folder and its subfolders (recursively)
    into a SQLite database for map hover data.
    """
    setup_database(db_path) # Ensure tables are set up before starting insertions

    # Use glob to find all .json files in the folder and its subfolders
    json_files = glob.glob(os.path.join(folder_path, '**', '*.json'), recursive=True)

    if not json_files:
        print(f"No JSON files found in '{folder_path}' or its subdirectories.")
        return

    print(f"Found {len(json_files)} JSON files. Starting insertion...")
    for json_file in json_files:
        try:
            with open(json_file, 'r', encoding='utf-8') as f:
                data = json.load(f)
            insert_map_hover_snapshot(data, json_file, db_path) # Pass full path for date extraction
        except FileNotFoundError:
            print(f"Error: JSON file not found (should not happen here): {json_file}")
        except json.JSONDecodeError:
            print(f"Error: Could not decode JSON from {json_file}. Skipping.")
        except PermissionError:
            print(f"Permission denied for file: {json_file}. Skipping.")
        except Exception as e:
            print(f"An unexpected error occurred while processing {json_file}: {e}")


# --- Execution ---
if __name__ == "__main__":
   

    load_folder_of_map_hover_jsons_to_sqlite(json_root_dir, db_file_path)

    #Verify data
    print("\n--- Verifying loaded data ---")
    conn = sqlite3.connect(db_file_path)
    cursor = conn.cursor()

    cursor.execute("SELECT id, success, code, year, period_id, source_file FROM MapHoverSnapshots LIMIT 5")
    print("\nMapHoverSnapshots Table (first 5 rows):")
    for row in cursor.fetchall():
        print(row)

    cursor.execute("SELECT snapshot_id, region_name, metric_type, metric_count, metric_amount FROM HoverDataEntries LIMIT 5")
    print("\nHoverDataEntries Table (first 5 rows):")
    for row in cursor.fetchall():
        print(row)

    cursor.execute("SELECT source_file, COUNT(*) FROM MapHoverSnapshots GROUP BY source_file")
    print("\nSnapshots loaded per source file:")
    for row in cursor.fetchall():
        print(row)
    
    cursor.execute("SELECT year, period_id, COUNT(*) FROM MapHoverSnapshots GROUP BY year, period_id ORDER BY year, period_id")
    print("\nSnapshots per Year and Period:")
    for row in cursor.fetchall():
        print(row)

    conn.close()
# Out:
# Database tables created/ensured for map hover data.
# Found 703 JSON files. Starting insertion...
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
#
# --- Verifying loaded data ---
#
# MapHoverSnapshots Table (first 5 rows):
# (1, 1, 'SUCCESS', 2020, 2, '2.json')
# (2, 1, 'SUCCESS', 2020, 3, '3.json')
# (3, 1, 'SUCCESS', 2020, 4, '4.json')
# (4, 1, 'SUCCESS', 2021, 1, '1.json')
#
# HoverDataEntries Table (first 5 rows):
#
# Snapshots loaded per source file:
# ('1.json', 1)
# ('2.json', 1)
# ('3.json', 1)
# ('4.json', 1)
#
# Snapshots per Year and Period:
# (2020, 2, 1)
# (2020, 3, 1)
# (2020, 4, 1)
# (2021, 1, 1)

# %% [raw]
# ## struccture of map hover in json format

# %%
import json

with open("C:\\Users\\mukta\\OneDrive\\Desktop\\Phonepay\\pulse\\data\\map\\insurance\\hover\\country\\india\\2020\\2.json", "r") as f:
    data = json.load(f)
print(json.dumps(data, indent=4))
# Out:
# {
#     "success": true,
#     "code": "SUCCESS",
#     "data": {
#         "hoverDataList": [
#             {
#                 "name": "puducherry",
#                 "metric": [
#                     {
#                         "type": "TOTAL",
#                         "count": 112,
#                         "amount": 22251.0
#                     }
#                 ]
#             },
#             {
#                 "name": "tamil nadu",
#                 "metric": [
#                     {
#                         "type": "TOTAL",
#                         "count": 5473,
#                         "amount": 1075552.0
#                     }
#                 ]
#             },
#             {
#                 "name": "uttar pradesh",
#                 "metric": [
#                     {
#                         "type": "TOTAL",
#                         "count": 9884,
#                         "amount": 1912266.0
#                     }
#                 ]
#             },
#             {
#                 "name": "madhya pradesh",
#                 "metric": [
#                     {
#                         "type": "TOTAL",
#                         "count": 6283,
#                         "amount": 1198701.0
#                     }
#                 ]
#             },
#             {
#                 "name": "andhra pradesh",
#                 "metric": [
#                     {
#                         "type": "TOTAL",
#                         "count": 22104,
#                         "amount": 3982391.0
#                     }
#                 ]
#             },
#             {
#                 "name": "tripura",
#                 "metric": [
#                     {
#                         "type": "TOTAL",
#                         "count": 88,
#                         "amount": 22054.0
#                     }
#                 ]
#             },
#             {
#                 "name": "manipur",
#                 "metric": [
#                     {
#                         "type": "TOTAL",
#                         "count": 55,
#                         "amount": 12554.0
#                     }
#                 ]
#             },
#             {
#                 "name": "maharashtra",
#                 "metric": [
#                     {
#                         "type": "TOTAL",
#                         "count": 39836,
#                         "amount": 6879717.0
#                     }
#                 ]
#             },
#             {
#                 "name": "dadra & nagar haveli & daman & diu",
#                 "metric": [
#                     {
#                         "type": "TOTAL",
#                         "count": 651,
#                         "amount": 101029.0
#                     }
#                 ]
#             },
#             {
#                 "name": "meghalaya",
#                 "metric": [
#                     {
#                         "type": "TOTAL",
#                         "count": 41,
#                         "amount": 8829.0
#                     }
#                 ]
#             },
#             {
#                 "name": "andaman & nicobar islands",
#                 "metric": [
#                     {
#                         "type": "TOTAL",
#                         "count": 6,
#                         "amount": 1360.0
#                     }
#                 ]
#             },
#             {
#                 "name": "haryana",
#                 "metric": [
#                     {
#                         "type": "TOTAL",
#                         "count": 6321,
#                         "amount": 1179814.0
#                     }
#                 ]
#             },
#             {
#                 "name": "rajasthan",
#                 "metric": [
#                     {
#                         "type": "TOTAL",
#                         "count": 5373,
#                         "amount": 1095933.0
#                     }
#                 ]
#             },
#             {
#                 "name": "ladakh",
#                 "metric": [
#                     {
#                         "type": "TOTAL",
#                         "count": 14,
#                         "amount": 2538.0
#                     }
#                 ]
#             },
#             {
#                 "name": "punjab",
#                 "metric": [
#                     {
#                         "type": "TOTAL",
#                         "count": 2036,
#                         "amount": 399452.0
#                     }
#                 ]
#             },
#             {
#                 "name": "assam",
#                 "metric": [
#                     {
#                         "type": "TOTAL",
#                         "count": 978,
#                         "amount": 210034.0
#                     }
#                 ]
#             },
#             {
#                 "name": "jharkhand",
#                 "metric": [
#                     {
#                         "type": "TOTAL",
#                         "count": 2063,
#                         "amount": 405031.0
#                     }
#                 ]
#             },
#             {
#                 "name": "odisha",
#                 "metric": [
#                     {
#                         "type": "TOTAL",
#                         "count": 2981,
#                         "amount": 615193.0
#                     }
#                 ]
#             },
#             {
#                 "name": "bihar",
#                 "metric": [
#                     {
#                         "type": "TOTAL",
#                         "count": 2816,
#                         "amount": 595621.0
#                     }
#                 ]
#             },
#             {
#                 "name": "kerala",
#                 "metric": [
#                     {
#                         "type": "TOTAL",
#                         "count": 1588,
#                         "amount": 360216.0
#                     }
#                 ]
#             },
#             {
#                 "name": "karnataka",
#                 "metric": [
#                     {
#                         "type": "TOTAL",
#                         "count": 27358,
#                         "amount": 4794150.0
#                     }
#                 ]
#             },
#             {
#                 "name": "chandigarh",
#                 "metric": [
#                     {
#                         "type": "TOTAL",
#                         "count": 149,
#                         "amount": 29537.0
#                     }
#                 ]
#             },
#             {
#                 "name": "telangana",
#                 "metric": [
#                     {
#                         "type": "TOTAL",
#                         "count": 19003,
#                         "amount": 3419453.0
#                     }
#                 ]
#             },
#             {
#                 "name": "himachal pradesh",
#                 "metric": [
#                     {
#                         "type": "TOTAL",
#                         "count": 392,
#                         "amount": 77936.0
#                     }
#                 ]
#             },
#             {
#                 "name": "west bengal",
#                 "metric": [
#                     {
#                         "type": "TOTAL",
#                         "count": 7619,
#                         "amount": 1432764.0
#                     }
#                 ]
#             },
#             {
#                 "name": "gujarat",
#                 "metric": [
#                     {
#                         "type": "TOTAL",
#                         "count": 7697,
#                         "amount": 1430591.0
#                     }
#                 ]
#             },
#             {
#                 "name": "sikkim",
#                 "metric": [
#                     {
#                         "type": "TOTAL",
#                         "count": 21,
#                         "amount": 4789.0
#                     }
#                 ]
#             },
#             {
#                 "name": "nagaland",
#                 "metric": [
#                     {
#                         "type": "TOTAL",
#                         "count": 41,
#                         "amount": 9791.0
#                     }
#                 ]
#             },
#             {
#                 "name": "mizoram",
#                 "metric": [
#                     {
#                         "type": "TOTAL",
#                         "count": 31,
#                         "amount": 7322.0
#                     }
#                 ]
#             },
#             {
#                 "name": "chhattisgarh",
#                 "metric": [
#                     {
#                         "type": "TOTAL",
#                         "count": 1346,
#                         "amount": 279005.0
#                     }
#                 ]
#             },
#             {
#                 "name": "jammu & kashmir",
#                 "metric": [
#                     {
#                         "type": "TOTAL",
#                         "count": 206,
#                         "amount": 48484.0
#                     }
#                 ]
#             },
#             {
#                 "name": "goa",
#                 "metric": [
#                     {
#                         "type": "TOTAL",
#                         "count": 341,
#                         "amount": 71100.0
#                     }
#                 ]
#             },
#             {
#                 "name": "arunachal pradesh",
#                 "metric": [
#                     {
#                         "type": "TOTAL",
#                         "count": 65,
#                         "amount": 14329.0
#                     }
#                 ]
#             },
#             {
#                 "name": "delhi",
#                 "metric": [
#                     {
#                         "type": "TOTAL",
#                         "count": 11716,
#                         "amount": 1897480.0
#                     }
#                 ]
#             },
#             {
#                 "name": "uttarakhand",
#                 "metric": [
#                     {
#                         "type": "TOTAL",
#                         "count": 660,
#                         "amount": 134899.0
#                     }
#                 ]
#             }
#         ]
#     },
#     "responseTimestamp": 1692610792974
# }

# %%
json_root_dir = "C:\\Users\\mukta\\OneDrive\\Desktop\\Phonepay\\pulse\\data\\map\\transaction\\hover\\country\india" 

# Define the path for your SQLite database file
db_file_path = "map_transaction_data.db" # <--- NEW DATABASE NAME

# --- Utility Function to Extract Date/Period from Path ---
def extract_period_from_path(file_path):
    """
    Extracts year and a generic period ID from a file path using a common pattern like /YYYY/PERIOD.json
    Returns (year, period) or (None, None) if not found.
    """
    # Regex to find /YYYY/NUMBER.json pattern
    match = re.search(r'[\\/](\d{4})[\\/](\d{1,3})\.json$', file_path)
    if match:
        return int(match.group(1)), int(match.group(2))
    
    return None, None # Default if no pattern matches

# --- Database Setup Functions ---
def setup_database(db_path):
    """Sets up the SQLite database tables for map hover data."""
    conn = None
    try:
        conn = sqlite3.connect(db_path)
        cursor = conn.cursor()

        # 1. Create the MapHoverSnapshots table
        cursor.execute('''
            CREATE TABLE IF NOT EXISTS MapHoverSnapshots (
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                success INTEGER, -- SQLite uses 0 for False, 1 for True
                code TEXT,
                year INTEGER,
                period_id INTEGER, -- Month, quarter, or arbitrary ID
                source_file TEXT UNIQUE
            )
        ''')

        # 2. Create the HoverDataEntries table
        cursor.execute('''
            CREATE TABLE IF NOT EXISTS HoverDataEntries (
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                snapshot_id INTEGER,
                region_name TEXT,
                metric_type TEXT,
                metric_count INTEGER,
                metric_amount REAL,
                FOREIGN KEY (snapshot_id) REFERENCES MapHoverSnapshots(id)
            )
        ''')

        conn.commit()
        print("Database tables created/ensured for map hover data.")
    except sqlite3.Error as e:
        print(f"Error setting up database: {e}")
    finally:
        if conn:
            conn.close()

# --- Data Insertion Function ---
def insert_map_hover_snapshot(json_data, source_full_path, db_path):
    """
    Inserts data from a single parsed map hover JSON object into the SQLite database.
    """
    conn = None
    source_filename = os.path.basename(source_full_path)
    
    # Extract year and period_id from the full file path
    year, period_id = extract_period_from_path(source_full_path)

    try:
        conn = sqlite3.connect(db_path)
        cursor = conn.cursor()

        # Extract data from the JSON object
        success = 1 if json_data.get("success") else 0 # Convert boolean to integer
        code = json_data.get("code")
        
        # Insert into MapHoverSnapshots table
        cursor.execute('''
            INSERT OR IGNORE INTO MapHoverSnapshots (
                success, code, year, period_id, source_file
            )
            VALUES (?, ?, ?, ?, ?)
        ''', (
            success, code, year, period_id, source_filename
        ))

        # If the snapshot was actually inserted, get its ID
        if cursor.rowcount > 0:
            snapshot_id = cursor.lastrowid
            
            # Process hoverdatalist
            hover_data_list = json_data.get("data", {}).get("hoverdatalist", [])
            for entry in hover_data_list:
                name = entry.get("name")
                metric = entry.get("metric", {})
                metric_type = metric.get("type")
                metric_count = metric.get("count")
                metric_amount = metric.get("amount")

                cursor.execute('''
                    INSERT INTO HoverDataEntries (snapshot_id, region_name, metric_type, metric_count, metric_amount)
                    VALUES (?, ?, ?, ?, ?)
                ''', (snapshot_id, name, metric_type, metric_count, metric_amount))
            conn.commit()
            print(f"Successfully inserted data for snapshot '{source_filename}'.")
        else:
            print(f"Snapshot '{source_filename}' already exists in database. Skipping insertion.")

    except sqlite3.Error as e:
        print(f"Error inserting data from '{source_filename}': {e}")
        if conn:
            conn.rollback()
    except Exception as e: # Catch other potential errors during parsing/accessing
        print(f"General error processing '{source_filename}': {e}")
    finally:
        if conn:
            conn.close()

# --- Main Loading Logic ---
def load_folder_of_map_hover_jsons_to_sqlite(folder_path, db_path):
    """
    Loads all JSON files from a specified folder and its subfolders (recursively)
    into a SQLite database for map hover data.
    """
    setup_database(db_path) # Ensure tables are set up before starting insertions

    # Use glob to find all .json files in the folder and its subfolders
    json_files = glob.glob(os.path.join(folder_path, '**', '*.json'), recursive=True)

    if not json_files:
        print(f"No JSON files found in '{folder_path}' or its subdirectories.")
        return

    print(f"Found {len(json_files)} JSON files. Starting insertion...")
    for json_file in json_files:
        try:
            with open(json_file, 'r', encoding='utf-8') as f:
                data = json.load(f)
            insert_map_hover_snapshot(data, json_file, db_path) # Pass full path for date extraction
        except FileNotFoundError:
            print(f"Error: JSON file not found (should not happen here): {json_file}")
        except json.JSONDecodeError:
            print(f"Error: Could not decode JSON from {json_file}. Skipping.")
        except PermissionError:
            print(f"Permission denied for file: {json_file}. Skipping.")
        except Exception as e:
            print(f"An unexpected error occurred while processing {json_file}: {e}")


# --- Execution ---
if __name__ == "__main__":
   

    load_folder_of_map_hover_jsons_to_sqlite(json_root_dir, db_file_path)

    # Verify data
    print("\n--- Verifying loaded data ---")
    conn = sqlite3.connect(db_file_path)
    cursor = conn.cursor()

    cursor.execute("SELECT id, success, code, year, period_id, source_file FROM MapHoverSnapshots LIMIT 5")
    print("\nMapHoverSnapshots Table (first 5 rows):")
    for row in cursor.fetchall():
        print(row)

    cursor.execute("SELECT snapshot_id, region_name, metric_type, metric_count, metric_amount FROM HoverDataEntries LIMIT 5")
    print("\nHoverDataEntries Table (first 5 rows):")
    for row in cursor.fetchall():
        print(row)

    cursor.execute("SELECT source_file, COUNT(*) FROM MapHoverSnapshots GROUP BY source_file")
    print("\nSnapshots loaded per source file:")
    for row in cursor.fetchall():
        print(row)
    
    cursor.execute("SELECT year, period_id, COUNT(*) FROM MapHoverSnapshots GROUP BY year, period_id ORDER BY year, period_id")
    print("\nSnapshots per Year and Period:")
    for row in cursor.fetchall():
        print(row)

    conn.close()
# Out:
# Database tables created/ensured for map hover data.
# Found 1036 JSON files. Starting insertion...
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# <>:1: SyntaxWarning: invalid escape sequence '\i'
# <>:1: SyntaxWarning: invalid escape sequence '\i'
# C:\Users\mukta\AppData\Local\Temp\ipykernel_23436\2948765.py:1: SyntaxWarning: invalid escape sequence '\i'
#   json_root_dir = "C:\\Users\\mukta\\OneDrive\\Desktop\\Phonepay\\pulse\\data\\map\\transaction\\hover\\country\india"
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# ...
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
#
# --- Verifying loaded data ---
#
# MapHoverSnapshots Table (first 5 rows):
# (1, 1, 'SUCCESS', 2018, 1, '1.json')
# (2, 1, 'SUCCESS', 2018, 2, '2.json')
# (3, 1, 'SUCCESS', 2018, 3, '3.json')
# (4, 1, 'SUCCESS', 2018, 4, '4.json')
#
# HoverDataEntries Table (first 5 rows):
#
# Snapshots loaded per source file:
# ('1.json', 1)
# ('2.json', 1)
# ('3.json', 1)
# ('4.json', 1)
#
# Snapshots per Year and Period:
# (2018, 1, 1)
# (2018, 2, 1)
# (2018, 3, 1)
# (2018, 4, 1)

# %%
json_root_dir = "C:\\Users\\mukta\\OneDrive\\Desktop\\Phonepay\\pulse\\data\\map\\user\\hover\\country\\india" 

# Define the path for your SQLite database file
db_file_path = "map_user_data.db" # <--- NEW DATABASE NAME

# --- Utility Function to Extract Date/Period from Path ---
def extract_period_from_path(file_path):
    """
    Extracts year and a generic period ID from a file path using a common pattern like /YYYY/PERIOD.json
    Returns (year, period) or (None, None) if not found.
    """
    # Regex to find /YYYY/NUMBER.json pattern
    match = re.search(r'[\\/](\d{4})[\\/](\d{1,3})\.json$', file_path)
    if match:
        return int(match.group(1)), int(match.group(2))
    
    return None, None # Default if no pattern matches

# --- Database Setup Functions ---
def setup_database(db_path):
    """Sets up the SQLite database tables for map hover data."""
    conn = None
    try:
        conn = sqlite3.connect(db_path)
        cursor = conn.cursor()

        # 1. Create the MapHoverSnapshots table
        cursor.execute('''
            CREATE TABLE IF NOT EXISTS MapHoverSnapshots (
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                success INTEGER, -- SQLite uses 0 for False, 1 for True
                code TEXT,
                year INTEGER,
                period_id INTEGER, -- Month, quarter, or arbitrary ID
                source_file TEXT UNIQUE
            )
        ''')

        # 2. Create the HoverDataEntries table
        cursor.execute('''
            CREATE TABLE IF NOT EXISTS HoverDataEntries (
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                snapshot_id INTEGER,
                region_name TEXT,
                metric_type TEXT,
                metric_count INTEGER,
                metric_amount REAL,
                FOREIGN KEY (snapshot_id) REFERENCES MapHoverSnapshots(id)
            )
        ''')

        conn.commit()
        print("Database tables created/ensured for map hover data.")
    except sqlite3.Error as e:
        print(f"Error setting up database: {e}")
    finally:
        if conn:
            conn.close()

# --- Data Insertion Function ---
def insert_map_hover_snapshot(json_data, source_full_path, db_path):
    """
    Inserts data from a single parsed map hover JSON object into the SQLite database.
    """
    conn = None
    source_filename = os.path.basename(source_full_path)
    
    # Extract year and period_id from the full file path
    year, period_id = extract_period_from_path(source_full_path)

    try:
        conn = sqlite3.connect(db_path)
        cursor = conn.cursor()

        # Extract data from the JSON object
        success = 1 if json_data.get("success") else 0 # Convert boolean to integer
        code = json_data.get("code")
        
        # Insert into MapHoverSnapshots table
        cursor.execute('''
            INSERT OR IGNORE INTO MapHoverSnapshots (
                success, code, year, period_id, source_file
            )
            VALUES (?, ?, ?, ?, ?)
        ''', (
            success, code, year, period_id, source_filename
        ))

        # If the snapshot was actually inserted, get its ID
        if cursor.rowcount > 0:
            snapshot_id = cursor.lastrowid
            
            # Process hoverdatalist
            hover_data_list = json_data.get("data", {}).get("hoverdatalist", [])
            for entry in hover_data_list:
                name = entry.get("name")
                metric = entry.get("metric", {})
                metric_type = metric.get("type")
                metric_count = metric.get("count")
                metric_amount = metric.get("amount")

                cursor.execute('''
                    INSERT INTO HoverDataEntries (snapshot_id, region_name, metric_type, metric_count, metric_amount)
                    VALUES (?, ?, ?, ?, ?)
                ''', (snapshot_id, name, metric_type, metric_count, metric_amount))
            conn.commit()
            print(f"Successfully inserted data for snapshot '{source_filename}'.")
        else:
            print(f"Snapshot '{source_filename}' already exists in database. Skipping insertion.")

    except sqlite3.Error as e:
        print(f"Error inserting data from '{source_filename}': {e}")
        if conn:
            conn.rollback()
    except Exception as e: # Catch other potential errors during parsing/accessing
        print(f"General error processing '{source_filename}': {e}")
    finally:
        if conn:
            conn.close()

# --- Main Loading Logic ---
def load_folder_of_map_hover_jsons_to_sqlite(folder_path, db_path):
    """
    Loads all JSON files from a specified folder and its subfolders (recursively)
    into a SQLite database for map hover data.
    """
    setup_database(db_path) # Ensure tables are set up before starting insertions

    # Use glob to find all .json files in the folder and its subfolders
    json_files = glob.glob(os.path.join(folder_path, '**', '*.json'), recursive=True)

    if not json_files:
        print(f"No JSON files found in '{folder_path}' or its subdirectories.")
        return

    print(f"Found {len(json_files)} JSON files. Starting insertion...")
    for json_file in json_files:
        try:
            with open(json_file, 'r', encoding='utf-8') as f:
                data = json.load(f)
            insert_map_hover_snapshot(data, json_file, db_path) # Pass full path for date extraction
        except FileNotFoundError:
            print(f"Error: JSON file not found (should not happen here): {json_file}")
        except json.JSONDecodeError:
            print(f"Error: Could not decode JSON from {json_file}. Skipping.")
        except PermissionError:
            print(f"Permission denied for file: {json_file}. Skipping.")
        except Exception as e:
            print(f"An unexpected error occurred while processing {json_file}: {e}")


# --- Execution ---
if __name__ == "__main__":
    
    load_folder_of_map_hover_jsons_to_sqlite(json_root_dir, db_file_path)

    # Verify data
    print("\n--- Verifying loaded data ---")
    conn = sqlite3.connect(db_file_path)
    cursor = conn.cursor()

    cursor.execute("SELECT id, success, code, year, period_id, source_file FROM MapHoverSnapshots LIMIT 5")
    print("\nMapHoverSnapshots Table (first 5 rows):")
    for row in cursor.fetchall():
        print(row)

    cursor.execute("SELECT snapshot_id, region_name, metric_type, metric_count, metric_amount FROM HoverDataEntries LIMIT 5")
    print("\nHoverDataEntries Table (first 5 rows):")
    for row in cursor.fetchall():
        print(row)

    cursor.execute("SELECT source_file, COUNT(*) FROM MapHoverSnapshots GROUP BY source_file")
    print("\nSnapshots loaded per source file:")
    for row in cursor.fetchall():
        print(row)
    
    cursor.execute("SELECT year, period_id, COUNT(*) FROM MapHoverSnapshots GROUP BY year, period_id ORDER BY year, period_id")
    print("\nSnapshots per Year and Period:")
    for row in cursor.fetchall():
        print(row)

    conn.close()
# Out:
# Database tables created/ensured for map hover data.
# Found 1036 JSON files. Starting insertion...
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# ...
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
#
# --- Verifying loaded data ---
#
# MapHoverSnapshots Table (first 5 rows):
# (1, 1, 'SUCCESS', 2018, 1, '1.json')
# (2, 1, 'SUCCESS', 2018, 2, '2.json')
# (3, 1, 'SUCCESS', 2018, 3, '3.json')
# (4, 1, 'SUCCESS', 2018, 4, '4.json')
#
# HoverDataEntries Table (first 5 rows):
#
# Snapshots loaded per source file:
# ('1.json', 1)
# ('2.json', 1)
# ('3.json', 1)
# ('4.json', 1)
#
# Snapshots per Year and Period:
# (2018, 1, 1)
# (2018, 2, 1)
# (2018, 3, 1)
# (2018, 4, 1)

# %% [raw]
# ## structure of top insurence data in json format

# %%
import json

with open("C:\\Users\\mukta\\OneDrive\\Desktop\\Phonepay\\pulse\\data\\top\\insurance\\country\\india\\2020\\2.json", "r") as f:
    data = json.load(f)
print(json.dumps(data, indent=4))
# Out:
# {
#     "success": true,
#     "code": "SUCCESS",
#     "data": {
#         "states": [
#             {
#                 "entityName": "maharashtra",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 39836,
#                     "amount": 6879717.0
#                 }
#             },
#             {
#                 "entityName": "karnataka",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 27358,
#                     "amount": 4794150.0
#                 }
#             },
#             {
#                 "entityName": "andhra pradesh",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 22104,
#                     "amount": 3982391.0
#                 }
#             },
#             {
#                 "entityName": "telangana",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 19003,
#                     "amount": 3419453.0
#                 }
#             },
#             {
#                 "entityName": "delhi",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 11716,
#                     "amount": 1897480.0
#                 }
#             },
#             {
#                 "entityName": "uttar pradesh",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 9884,
#                     "amount": 1912266.0
#                 }
#             },
#             {
#                 "entityName": "gujarat",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 7697,
#                     "amount": 1430591.0
#                 }
#             },
#             {
#                 "entityName": "west bengal",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 7619,
#                     "amount": 1432764.0
#                 }
#             },
#             {
#                 "entityName": "haryana",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 6321,
#                     "amount": 1179814.0
#                 }
#             },
#             {
#                 "entityName": "madhya pradesh",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 6283,
#                     "amount": 1198701.0
#                 }
#             }
#         ],
#         "districts": [
#             {
#                 "entityName": "bengaluru urban",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 20040,
#                     "amount": 3301769.0
#                 }
#             },
#             {
#                 "entityName": "pune",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 8699,
#                     "amount": 1482628.0
#                 }
#             },
#             {
#                 "entityName": "thane",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 7559,
#                     "amount": 1221018.0
#                 }
#             },
#             {
#                 "entityName": "mumbai suburban",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 5780,
#                     "amount": 884439.0
#                 }
#             },
#             {
#                 "entityName": "hyderabad",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 4783,
#                     "amount": 805518.0
#                 }
#             },
#             {
#                 "entityName": "rangareddy",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 4495,
#                     "amount": 778492.0
#                 }
#             },
#             {
#                 "entityName": "medchal malkajgiri",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 4150,
#                     "amount": 711890.0
#                 }
#             },
#             {
#                 "entityName": "visakhapatnam",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 3504,
#                     "amount": 614212.0
#                 }
#             },
#             {
#                 "entityName": "aurangabad",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 2898,
#                     "amount": 509460.0
#                 }
#             },
#             {
#                 "entityName": "anantapur",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 2739,
#                     "amount": 485777.0
#                 }
#             }
#         ],
#         "pincodes": [
#             {
#                 "entityName": "560068",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 1076,
#                     "amount": 168415.0
#                 }
#             },
#             {
#                 "entityName": "560037",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 1034,
#                     "amount": 155914.0
#                 }
#             },
#             {
#                 "entityName": "110059",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 895,
#                     "amount": 132104.0
#                 }
#             },
#             {
#                 "entityName": "560076",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 802,
#                     "amount": 124790.0
#                 }
#             },
#             {
#                 "entityName": "500072",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 760,
#                     "amount": 122394.0
#                 }
#             },
#             {
#                 "entityName": "560078",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 742,
#                     "amount": 119673.0
#                 }
#             },
#             {
#                 "entityName": "421201",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 668,
#                     "amount": 104388.0
#                 }
#             },
#             {
#                 "entityName": "560100",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 651,
#                     "amount": 103528.0
#                 }
#             },
#             {
#                 "entityName": "431003",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 651,
#                     "amount": 107122.0
#                 }
#             },
#             {
#                 "entityName": "110092",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 638,
#                     "amount": 94570.0
#                 }
#             }
#         ]
#     },
#     "responseTimestamp": 1692610793302
# }

# %%
json_root_dir = "C:\\Users\\mukta\\OneDrive\\Desktop\\Phonepay\\pulse\\data\\top\\insurance\\country\\india" # <--- ADJUST THIS PATH

# Define the path for your SQLite database file
db_file_path = "top_insurance_data.db" # <--- NEW DATABASE NAME

# --- Utility Function to Extract Date/Period from Path ---
def extract_period_from_path(file_path):
    """
    Extracts year and a generic period ID from a file path using a common pattern like /YYYY/PERIOD.json
    Returns (year, period) or (None, None) if not found.
    """
    # Regex to find /YYYY/NUMBER.json pattern
    match = re.search(r'[\\/](\d{4})[\\/](\d{1,3})\.json$', file_path)
    if match:
        return int(match.group(1)), int(match.group(2))
    
    return None, None # Default if no pattern matches

# --- Database Setup Functions ---
def setup_database(db_path):
    """Sets up the SQLite database tables for top insurance data."""
    conn = None
    try:
        conn = sqlite3.connect(db_path)
        cursor = conn.cursor()

        # 1. Create the TopInsuranceSnapshots table
        cursor.execute('''
            CREATE TABLE IF NOT EXISTS TopInsuranceSnapshots (
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                success INTEGER, -- SQLite uses 0 for False, 1 for True
                code TEXT,
                year INTEGER,
                period_id INTEGER, -- Month, quarter, or arbitrary ID
                source_file TEXT UNIQUE
            )
        ''')

        # 2. Create the TopInsuranceEntities table
        cursor.execute('''
            CREATE TABLE IF NOT EXISTS TopInsuranceEntities (
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                snapshot_id INTEGER,
                entity_name TEXT,
                metric_type TEXT,
                metric_count INTEGER,
                metric_amount REAL,
                FOREIGN KEY (snapshot_id) REFERENCES TopInsuranceSnapshots(id)
            )
        ''')

        conn.commit()
        print("Database tables created/ensured for top insurance data.")
    except sqlite3.Error as e:
        print(f"Error setting up database: {e}")
    finally:
        if conn:
            conn.close()

# --- Data Insertion Function ---
def insert_top_insurance_snapshot(json_data, source_full_path, db_path):
    """
    Inserts data from a single parsed top insurance JSON object into the SQLite database.
    """
    conn = None
    source_filename = os.path.basename(source_full_path)
    
    # Extract year and period_id from the full file path
    year, period_id = extract_period_from_path(source_full_path)

    try:
        conn = sqlite3.connect(db_path)
        cursor = conn.cursor()

        # Extract data from the JSON object
        success = 1 if json_data.get("success") else 0 # Convert boolean to integer
        code = json_data.get("code")
        
        # Insert into TopInsuranceSnapshots table
        cursor.execute('''
            INSERT OR IGNORE INTO TopInsuranceSnapshots (
                success, code, year, period_id, source_file
            )
            VALUES (?, ?, ?, ?, ?)
        ''', (
            success, code, year, period_id, source_filename
        ))

        # If the snapshot was actually inserted, get its ID
        if cursor.rowcount > 0:
            snapshot_id = cursor.lastrowid
            
            # Process 'states' list
            states_list = json_data.get("data", {}).get("states", [])
            for entity_data in states_list:
                entity_name = entity_data.get("entityName")
                metric = entity_data.get("metric", {})
                metric_type = metric.get("type")
                metric_count = metric.get("count")
                metric_amount = metric.get("amount")

                cursor.execute('''
                    INSERT INTO TopInsuranceEntities (snapshot_id, entity_name, metric_type, metric_count, metric_amount)
                    VALUES (?, ?, ?, ?, ?)
                ''', (snapshot_id, entity_name, metric_type, metric_count, metric_amount))
            conn.commit()
            print(f"Successfully inserted data for snapshot '{source_filename}'.")
        else:
            print(f"Snapshot '{source_filename}' already exists in database. Skipping insertion.")

    except sqlite3.Error as e:
        print(f"Error inserting data from '{source_filename}': {e}")
        if conn:
            conn.rollback()
    except Exception as e: # Catch other potential errors during parsing/accessing
        print(f"General error processing '{source_filename}': {e}")
    finally:
        if conn:
            conn.close()

# --- Main Loading Logic ---
def load_folder_of_top_insurance_jsons_to_sqlite(folder_path, db_path):
    """
    Loads all JSON files from a specified folder and its subfolders (recursively)
    into a SQLite database for top insurance data.
    """
    setup_database(db_path) # Ensure tables are set up before starting insertions

    # Use glob to find all .json files in the folder and its subfolders
    json_files = glob.glob(os.path.join(folder_path, '**', '*.json'), recursive=True)

    if not json_files:
        print(f"No JSON files found in '{folder_path}' or its subdirectories.")
        return

    print(f"Found {len(json_files)} JSON files. Starting insertion...")
    for json_file in json_files:
        try:
            with open(json_file, 'r', encoding='utf-8') as f:
                data = json.load(f)
            insert_top_insurance_snapshot(data, json_file, db_path) # Pass full path for date extraction
        except FileNotFoundError:
            print(f"Error: JSON file not found (should not happen here): {json_file}")
        except json.JSONDecodeError:
            print(f"Error: Could not decode JSON from {json_file}. Skipping.")
        except PermissionError:
            print(f"Permission denied for file: {json_file}. Skipping.")
        except Exception as e:
            print(f"An unexpected error occurred while processing {json_file}: {e}")


# --- Execution ---
if __name__ == "__main__":
  

    load_folder_of_top_insurance_jsons_to_sqlite(json_root_dir, db_file_path)

    # Optional: Verify data
    print("\n--- Verifying loaded data ---")
    conn = sqlite3.connect(db_file_path)
    cursor = conn.cursor()

    cursor.execute("SELECT id, success, code, year, period_id, source_file FROM TopInsuranceSnapshots LIMIT 5")
    print("\nTopInsuranceSnapshots Table (first 5 rows):")
    for row in cursor.fetchall():
        print(row)

    cursor.execute("SELECT snapshot_id, entity_name, metric_type, metric_count, metric_amount FROM TopInsuranceEntities LIMIT 5")
    print("\nTopInsuranceEntities Table (first 5 rows):")
    for row in cursor.fetchall():
        print(row)

    cursor.execute("SELECT source_file, COUNT(*) FROM TopInsuranceSnapshots GROUP BY source_file")
    print("\nSnapshots loaded per source file:")
    for row in cursor.fetchall():
        print(row)
    
    cursor.execute("SELECT year, period_id, COUNT(*) FROM TopInsuranceSnapshots GROUP BY year, period_id ORDER BY year, period_id")
    print("\nSnapshots per Year and Period:")
    for row in cursor.fetchall():
        print(row)

    conn.close()
# Out:
# Database tables created/ensured for top insurance data.
# Found 703 JSON files. Starting insertion...
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
#
# --- Verifying loaded data ---
#
# TopInsuranceSnapshots Table (first 5 rows):
# (1, 1, 'SUCCESS', 2020, 2, '2.json')
# (2, 1, 'SUCCESS', 2020, 3, '3.json')
# (3, 1, 'SUCCESS', 2020, 4, '4.json')
# (4, 1, 'SUCCESS', 2021, 1, '1.json')
#
# TopInsuranceEntities Table (first 5 rows):
# (1, 'maharashtra', 'TOTAL', 39836, 6879717.0)
# (1, 'karnataka', 'TOTAL', 27358, 4794150.0)
# (1, 'andhra pradesh', 'TOTAL', 22104, 3982391.0)
# (1, 'telangana', 'TOTAL', 19003, 3419453.0)
# (1, 'delhi', 'TOTAL', 11716, 1897480.0)
#
# Snapshots loaded per source file:
# ('1.json', 1)
# ('2.json', 1)
# ('3.json', 1)
# ('4.json', 1)
#
# Snapshots per Year and Period:
# (2020, 2, 1)
# (2020, 3, 1)
# (2020, 4, 1)
# (2021, 1, 1)

# %% [raw]
# ## structure of top transaction data in json format

# %%
import json

with open("C:\\Users\\mukta\\OneDrive\\Desktop\\Phonepay\\pulse\\data\\top\\transaction\\country\\india\\2018\\1.json", "r") as f:
    data = json.load(f)
print(json.dumps(data, indent=4))
# Out:
# {
#     "success": true,
#     "code": "SUCCESS",
#     "data": {
#         "states": [
#             {
#                 "entityName": "maharashtra",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 16387034,
#                     "amount": 21711613257.725674
#                 }
#             },
#             {
#                 "entityName": "uttar pradesh",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 12537805,
#                     "amount": 13939970923.223106
#                 }
#             },
#             {
#                 "entityName": "karnataka",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 12016899,
#                     "amount": 19217895314.012802
#                 }
#             },
#             {
#                 "entityName": "west bengal",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 11710225,
#                     "amount": 10625978552.140453
#                 }
#             },
#             {
#                 "entityName": "andhra pradesh",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 9039585,
#                     "amount": 11996276391.823706
#                 }
#             },
#             {
#                 "entityName": "telangana",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 8522766,
#                     "amount": 13308204118.542435
#                 }
#             },
#             {
#                 "entityName": "madhya pradesh",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 8025395,
#                     "amount": 8681603403.446348
#                 }
#             },
#             {
#                 "entityName": "rajasthan",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 7591690,
#                     "amount": 8926293130.72684
#                 }
#             },
#             {
#                 "entityName": "delhi",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 7122754,
#                     "amount": 11211503806.91996
#                 }
#             },
#             {
#                 "entityName": "tamil nadu",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 6726622,
#                     "amount": 11261557697.516891
#                 }
#             }
#         ],
#         "districts": [
#             {
#                 "entityName": "bengaluru urban",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 8306513,
#                     "amount": 14162750303.06484
#                 }
#             },
#             {
#                 "entityName": "pune",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 3842929,
#                     "amount": 5378982326.835919
#                 }
#             },
#             {
#                 "entityName": "central delhi",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 2997714,
#                     "amount": 4312145216.274474
#                 }
#             },
#             {
#                 "entityName": "mumbai",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 2671029,
#                     "amount": 3923116793.952079
#                 }
#             },
#             {
#                 "entityName": "chennai",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 2656230,
#                     "amount": 4281137762.522443
#                 }
#             },
#             {
#                 "entityName": "hyderabad",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 2545507,
#                     "amount": 4287223789.76588
#                 }
#             },
#             {
#                 "entityName": "jaipur",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 2417174,
#                     "amount": 2953086960.1413727
#                 }
#             },
#             {
#                 "entityName": "birbhum",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 2125816,
#                     "amount": 2520486412.452376
#                 }
#             },
#             {
#                 "entityName": "kolkata",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 2043129,
#                     "amount": 2753347660.1429114
#                 }
#             },
#             {
#                 "entityName": "bhopal",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 1704495,
#                     "amount": 1905473874.8326716
#                 }
#             }
#         ],
#         "pincodes": [
#             {
#                 "entityName": "560001",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 2917356,
#                     "amount": 4684262246.184548
#                 }
#             },
#             {
#                 "entityName": "110006",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 2636324,
#                     "amount": 3714139312.238586
#                 }
#             },
#             {
#                 "entityName": "400008",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 2227885,
#                     "amount": 3105208723.475169
#                 }
#             },
#             {
#                 "entityName": "600003",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 2010196,
#                     "amount": 2997847000.265506
#                 }
#             },
#             {
#                 "entityName": "731101",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 1764956,
#                     "amount": 2366771285.7278423
#                 }
#             },
#             {
#                 "entityName": "700009",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 1390629,
#                     "amount": 1851145374.4001179
#                 }
#             },
#             {
#                 "entityName": "411001",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 1055656,
#                     "amount": 1413523605.5956619
#                 }
#             },
#             {
#                 "entityName": "500012",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 933013,
#                     "amount": 1643061976.4262943
#                 }
#             },
#             {
#                 "entityName": "462001",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 832846,
#                     "amount": 898730606.684653
#                 }
#             },
#             {
#                 "entityName": "201301",
#                 "metric": {
#                     "type": "TOTAL",
#                     "count": 690196,
#                     "amount": 987613438.9540119
#                 }
#             }
#         ]
#     },
#     "responseTimestamp": 1630501481910
# }

# %%
json_root_dir = "C:\\Users\\mukta\\OneDrive\\Desktop\\Phonepay\\pulse\\data\\top\\transaction\\country\\india" # <--- ADJUST THIS PATH

# Define the path for your SQLite database file
db_file_path = "top_transaction_data.db" # <--- NEW DATABASE NAME

# --- Utility Function to Extract Date/Period from Path ---
def extract_period_from_path(file_path):
    """
    Extracts year and a generic period ID from a file path using a common pattern like /YYYY/PERIOD.json
    Returns (year, period) or (None, None) if not found.
    """
    # Regex to find /YYYY/NUMBER.json pattern
    match = re.search(r'[\\/](\d{4})[\\/](\d{1,3})\.json$', file_path)
    if match:
        return int(match.group(1)), int(match.group(2))
    
    return None, None # Default if no pattern matches

# --- Database Setup Functions ---
def setup_database(db_path):
    """Sets up the SQLite database tables for top insurance data."""
    conn = None
    try:
        conn = sqlite3.connect(db_path)
        cursor = conn.cursor()

        # 1. Create the TopInsuranceSnapshots table
        cursor.execute('''
            CREATE TABLE IF NOT EXISTS TopInsuranceSnapshots (
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                success INTEGER, -- SQLite uses 0 for False, 1 for True
                code TEXT,
                year INTEGER,
                period_id INTEGER, -- Month, quarter, or arbitrary ID
                source_file TEXT UNIQUE
            )
        ''')

        # 2. Create the TopInsuranceEntities table
        cursor.execute('''
            CREATE TABLE IF NOT EXISTS TopInsuranceEntities (
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                snapshot_id INTEGER,
                entity_name TEXT,
                metric_type TEXT,
                metric_count INTEGER,
                metric_amount REAL,
                FOREIGN KEY (snapshot_id) REFERENCES TopInsuranceSnapshots(id)
            )
        ''')

        conn.commit()
        print("Database tables created/ensured for top insurance data.")
    except sqlite3.Error as e:
        print(f"Error setting up database: {e}")
    finally:
        if conn:
            conn.close()

# --- Data Insertion Function ---
def insert_top_insurance_snapshot(json_data, source_full_path, db_path):
    """
    Inserts data from a single parsed top insurance JSON object into the SQLite database.
    """
    conn = None
    source_filename = os.path.basename(source_full_path)
    
    # Extract year and period_id from the full file path
    year, period_id = extract_period_from_path(source_full_path)

    try:
        conn = sqlite3.connect(db_path)
        cursor = conn.cursor()

        # Extract data from the JSON object
        success = 1 if json_data.get("success") else 0 # Convert boolean to integer
        code = json_data.get("code")
        
        # Insert into TopInsuranceSnapshots table
        cursor.execute('''
            INSERT OR IGNORE INTO TopInsuranceSnapshots (
                success, code, year, period_id, source_file
            )
            VALUES (?, ?, ?, ?, ?)
        ''', (
            success, code, year, period_id, source_filename
        ))

        # If the snapshot was actually inserted, get its ID
        if cursor.rowcount > 0:
            snapshot_id = cursor.lastrowid
            
            # Process 'states' list
            states_list = json_data.get("data", {}).get("states", [])
            for entity_data in states_list:
                entity_name = entity_data.get("entityName")
                metric = entity_data.get("metric", {})
                metric_type = metric.get("type")
                metric_count = metric.get("count")
                metric_amount = metric.get("amount")

                cursor.execute('''
                    INSERT INTO TopInsuranceEntities (snapshot_id, entity_name, metric_type, metric_count, metric_amount)
                    VALUES (?, ?, ?, ?, ?)
                ''', (snapshot_id, entity_name, metric_type, metric_count, metric_amount))
            conn.commit()
            print(f"Successfully inserted data for snapshot '{source_filename}'.")
        else:
            print(f"Snapshot '{source_filename}' already exists in database. Skipping insertion.")

    except sqlite3.Error as e:
        print(f"Error inserting data from '{source_filename}': {e}")
        if conn:
            conn.rollback()
    except Exception as e: # Catch other potential errors during parsing/accessing
        print(f"General error processing '{source_filename}': {e}")
    finally:
        if conn:
            conn.close()

# --- Main Loading Logic ---
def load_folder_of_top_insurance_jsons_to_sqlite(folder_path, db_path):
    """
    Loads all JSON files from a specified folder and its subfolders (recursively)
    into a SQLite database for top insurance data.
    """
    setup_database(db_path) # Ensure tables are set up before starting insertions

    # Use glob to find all .json files in the folder and its subfolders
    json_files = glob.glob(os.path.join(folder_path, '**', '*.json'), recursive=True)

    if not json_files:
        print(f"No JSON files found in '{folder_path}' or its subdirectories.")
        return

    print(f"Found {len(json_files)} JSON files. Starting insertion...")
    for json_file in json_files:
        try:
            with open(json_file, 'r', encoding='utf-8') as f:
                data = json.load(f)
            insert_top_insurance_snapshot(data, json_file, db_path) # Pass full path for date extraction
        except FileNotFoundError:
            print(f"Error: JSON file not found (should not happen here): {json_file}")
        except json.JSONDecodeError:
            print(f"Error: Could not decode JSON from {json_file}. Skipping.")
        except PermissionError:
            print(f"Permission denied for file: {json_file}. Skipping.")
        except Exception as e:
            print(f"An unexpected error occurred while processing {json_file}: {e}")


# --- Execution ---
if __name__ == "__main__":
   

    load_folder_of_top_insurance_jsons_to_sqlite(json_root_dir, db_file_path)

    # Verify data
    print("\n--- Verifying loaded data ---")
    conn = sqlite3.connect(db_file_path)
    cursor = conn.cursor()

    cursor.execute("SELECT id, success, code, year, period_id, source_file FROM TopInsuranceSnapshots LIMIT 5")
    print("\nTopInsuranceSnapshots Table (first 5 rows):")
    for row in cursor.fetchall():
        print(row)

    cursor.execute("SELECT snapshot_id, entity_name, metric_type, metric_count, metric_amount FROM TopInsuranceEntities LIMIT 5")
    print("\nTopInsuranceEntities Table (first 5 rows):")
    for row in cursor.fetchall():
        print(row)

    cursor.execute("SELECT source_file, COUNT(*) FROM TopInsuranceSnapshots GROUP BY source_file")
    print("\nSnapshots loaded per source file:")
    for row in cursor.fetchall():
        print(row)
    
    cursor.execute("SELECT year, period_id, COUNT(*) FROM TopInsuranceSnapshots GROUP BY year, period_id ORDER BY year, period_id")
    print("\nSnapshots per Year and Period:")
    for row in cursor.fetchall():
        print(row)

    conn.close()
# Out:
# Database tables created/ensured for top insurance data.
# Found 1036 JSON files. Starting insertion...
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# ...
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
#
# --- Verifying loaded data ---
#
# TopInsuranceSnapshots Table (first 5 rows):
# (1, 1, 'SUCCESS', 2018, 1, '1.json')
# (2, 1, 'SUCCESS', 2018, 2, '2.json')
# (3, 1, 'SUCCESS', 2018, 3, '3.json')
# (4, 1, 'SUCCESS', 2018, 4, '4.json')
#
# TopInsuranceEntities Table (first 5 rows):
# (1, 'maharashtra', 'TOTAL', 16387034, 21711613257.725674)
# (1, 'uttar pradesh', 'TOTAL', 12537805, 13939970923.223106)
# (1, 'karnataka', 'TOTAL', 12016899, 19217895314.012802)
# (1, 'west bengal', 'TOTAL', 11710225, 10625978552.140453)
# (1, 'andhra pradesh', 'TOTAL', 9039585, 11996276391.823706)
#
# Snapshots loaded per source file:
# ('1.json', 1)
# ('2.json', 1)
# ('3.json', 1)
# ('4.json', 1)
#
# Snapshots per Year and Period:
# (2018, 1, 1)
# (2018, 2, 1)
# (2018, 3, 1)
# (2018, 4, 1)

# %% [raw]
# ##structure of top user data in json format

# %%
import json

with open("C:\\Users\\mukta\\OneDrive\\Desktop\\Phonepay\\pulse\\data\\top\\user\\country\\india\\2018\\1.json", "r") as f:
    data = json.load(f)
print(json.dumps(data, indent=4))
# Out:
# {
#     "success": true,
#     "code": "SUCCESS",
#     "data": {
#         "states": [
#             {
#                 "name": "maharashtra",
#                 "registeredUsers": 6106994
#             },
#             {
#                 "name": "uttar pradesh",
#                 "registeredUsers": 4694250
#             },
#             {
#                 "name": "karnataka",
#                 "registeredUsers": 3717763
#             },
#             {
#                 "name": "andhra pradesh",
#                 "registeredUsers": 3336450
#             },
#             {
#                 "name": "telangana",
#                 "registeredUsers": 3315560
#             },
#             {
#                 "name": "rajasthan",
#                 "registeredUsers": 3158202
#             },
#             {
#                 "name": "gujarat",
#                 "registeredUsers": 2690048
#             },
#             {
#                 "name": "west bengal",
#                 "registeredUsers": 2604789
#             },
#             {
#                 "name": "madhya pradesh",
#                 "registeredUsers": 2553603
#             },
#             {
#                 "name": "bihar",
#                 "registeredUsers": 2133804
#             }
#         ],
#         "districts": [
#             {
#                 "name": "bengaluru urban",
#                 "registeredUsers": 1922368
#             },
#             {
#                 "name": "pune",
#                 "registeredUsers": 1211643
#             },
#             {
#                 "name": "jaipur",
#                 "registeredUsers": 900773
#             },
#             {
#                 "name": "mumbai suburban",
#                 "registeredUsers": 719300
#             },
#             {
#                 "name": "hyderabad",
#                 "registeredUsers": 655175
#             },
#             {
#                 "name": "rangareddy",
#                 "registeredUsers": 635175
#             },
#             {
#                 "name": "thane",
#                 "registeredUsers": 631864
#             },
#             {
#                 "name": "ahmadabad",
#                 "registeredUsers": 572811
#             },
#             {
#                 "name": "medchal malkajgiri",
#                 "registeredUsers": 549429
#             },
#             {
#                 "name": "visakhapatnam",
#                 "registeredUsers": 497187
#             }
#         ],
#         "pincodes": [
#             {
#                 "name": "201301",
#                 "registeredUsers": 114625
#             },
#             {
#                 "name": "500072",
#                 "registeredUsers": 105012
#             },
#             {
#                 "name": "560068",
#                 "registeredUsers": 98487
#             },
#             {
#                 "name": "110059",
#                 "registeredUsers": 95496
#             },
#             {
#                 "name": "110092",
#                 "registeredUsers": 83600
#             },
#             {
#                 "name": "122001",
#                 "registeredUsers": 82656
#             },
#             {
#                 "name": "560037",
#                 "registeredUsers": 75304
#             },
#             {
#                 "name": "395006",
#                 "registeredUsers": 72275
#             },
#             {
#                 "name": "800001",
#                 "registeredUsers": 71092
#             },
#             {
#                 "name": "302012",
#                 "registeredUsers": 68098
#             }
#         ]
#     },
#     "responseTimestamp": 1630501482414
# }

# %%
json_root_dir = "C:\\Users\\mukta\\OneDrive\\Desktop\\Phonepay\\pulse\\data\\top\\user\\country\\india" # <--- ADJUST THIS PATH

# Define the path for your SQLite database file
db_file_path = "top_user_data.db" # <--- NEW DATABASE NAME

# --- Utility Function to Extract Date/Period from Path ---
def extract_period_from_path(file_path):
    """
    Extracts year and a generic period ID from a file path using a common pattern like /YYYY/PERIOD.json
    Returns (year, period) or (None, None) if not found.
    """
    # Regex to find /YYYY/NUMBER.json pattern
    match = re.search(r'[\\/](\d{4})[\\/](\d{1,3})\.json$', file_path)
    if match:
        return int(match.group(1)), int(match.group(2))
    
    return None, None # Default if no pattern matches

# --- Database Setup Functions ---
def setup_database(db_path):
    """Sets up the SQLite database tables for top user data."""
    conn = None
    try:
        conn = sqlite3.connect(db_path)
        cursor = conn.cursor()

        # 1. Create the TopUserSnapshots table
        cursor.execute('''
            CREATE TABLE IF NOT EXISTS TopUserSnapshots (
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                success INTEGER, -- SQLite uses 0 for False, 1 for True
                code TEXT,
                year INTEGER,
                period_id INTEGER, -- Month, quarter, or arbitrary ID
                source_file TEXT UNIQUE
            )
        ''')

        # 2. Create the TopUserEntities table
        cursor.execute('''
            CREATE TABLE IF NOT EXISTS TopUserEntities (
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                snapshot_id INTEGER,
                entity_name TEXT,
                registeredUsers INTEGER,
                FOREIGN KEY (snapshot_id) REFERENCES TopUserSnapshots(id)
            )
        ''')

        conn.commit()
        print("Database tables created/ensured for top user data.")
    except sqlite3.Error as e:
        print(f"Error setting up database: {e}")
    finally:
        if conn:
            conn.close()

# --- Data Insertion Function ---
def insert_top_user_snapshot(json_data, source_full_path, db_path):
    """
    Inserts data from a single parsed top user JSON object into the SQLite database.
    """
    conn = None
    source_filename = os.path.basename(source_full_path)
    
    # Extract year and period_id from the full file path
    year, period_id = extract_period_from_path(source_full_path)

    try:
        conn = sqlite3.connect(db_path)
        cursor = conn.cursor()

        # Extract data from the JSON object
        success = 1 if json_data.get("success") else 0 # Convert boolean to integer
        code = json_data.get("code")
        
        # Insert into TopUserSnapshots table
        cursor.execute('''
            INSERT OR IGNORE INTO TopUserSnapshots (
                success, code, year, period_id, source_file
            )
            VALUES (?, ?, ?, ?, ?)
        ''', (
            success, code, year, period_id, source_filename
        ))

        # If the snapshot was actually inserted, get its ID
        if cursor.rowcount > 0:
            snapshot_id = cursor.lastrowid
            
            # Process 'states' list
            states_list = json_data.get("data", {}).get("states", [])
            for entity_data in states_list:
                entity_name = entity_data.get("name") # "name" for top user
                registered_users = entity_data.get("registeredUsers")

                cursor.execute('''
                    INSERT INTO TopUserEntities (snapshot_id, entity_name, registeredUsers)
                    VALUES (?, ?, ?)
                ''', (snapshot_id, entity_name, registered_users))
            conn.commit()
            print(f"Successfully inserted data for snapshot '{source_filename}'.")
        else:
            print(f"Snapshot '{source_filename}' already exists in database. Skipping insertion.")

    except sqlite3.Error as e:
        print(f"Error inserting data from '{source_filename}': {e}")
        if conn:
            conn.rollback()
    except Exception as e: # Catch other potential errors during parsing/accessing
        print(f"General error processing '{source_filename}': {e}")
    finally:
        if conn:
            conn.close()

# --- Main Loading Logic ---
def load_folder_of_top_user_jsons_to_sqlite(folder_path, db_path):
    """
    Loads all JSON files from a specified folder and its subfolders (recursively)
    into a SQLite database for top user data.
    """
    setup_database(db_path) # Ensure tables are set up before starting insertions

    # Use glob to find all .json files in the folder and its subfolders
    json_files = glob.glob(os.path.join(folder_path, '**', '*.json'), recursive=True)

    if not json_files:
        print(f"No JSON files found in '{folder_path}' or its subdirectories.")
        return

    print(f"Found {len(json_files)} JSON files. Starting insertion...")
    for json_file in json_files:
        try:
            with open(json_file, 'r', encoding='utf-8') as f:
                data = json.load(f)
            insert_top_user_snapshot(data, json_file, db_path) # Pass full path for date extraction
        except FileNotFoundError:
            print(f"Error: JSON file not found (should not happen here): {json_file}")
        except json.JSONDecodeError:
            print(f"Error: Could not decode JSON from {json_file}. Skipping.")
        except PermissionError:
            print(f"Permission denied for file: {json_file}. Skipping.")
        except Exception as e:
            print(f"An unexpected error occurred while processing {json_file}: {e}")


# --- Execution ---
if __name__ == "__main__":


    load_folder_of_top_user_jsons_to_sqlite(json_root_dir, db_file_path)

    # Verify data
    print("\n--- Verifying loaded data ---")
    conn = sqlite3.connect(db_file_path)
    cursor = conn.cursor()

    cursor.execute("SELECT id, success, code, year, period_id, source_file FROM TopUserSnapshots LIMIT 5")
    print("\nTopUserSnapshots Table (first 5 rows):")
    for row in cursor.fetchall():
        print(row)

    cursor.execute("SELECT snapshot_id, entity_name, registeredUsers FROM TopUserEntities LIMIT 5")
    print("\nTopUserEntities Table (first 5 rows):")
    for row in cursor.fetchall():
        print(row)

    cursor.execute("SELECT source_file, COUNT(*) FROM TopUserSnapshots GROUP BY source_file")
    print("\nSnapshots loaded per source file:")
    for row in cursor.fetchall():
        print(row)
    
    cursor.execute("SELECT year, period_id, COUNT(*) FROM TopUserSnapshots GROUP BY year, period_id ORDER BY year, period_id")
    print("\nSnapshots per Year and Period:")
    for row in cursor.fetchall():
        print(row)

    conn.close()
# Out:
# Database tables created/ensured for top user data.
# Found 1036 JSON files. Starting insertion...
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# ...
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
# Snapshot '1.json' already exists in database. Skipping insertion.
# Snapshot '2.json' already exists in database. Skipping insertion.
# Snapshot '3.json' already exists in database. Skipping insertion.
# Snapshot '4.json' already exists in database. Skipping insertion.
#
# --- Verifying loaded data ---
#
# TopUserSnapshots Table (first 5 rows):
# (1, 1, 'SUCCESS', 2018, 1, '1.json')
# (2, 1, 'SUCCESS', 2018, 2, '2.json')
# (3, 1, 'SUCCESS', 2018, 3, '3.json')
# (4, 1, 'SUCCESS', 2018, 4, '4.json')
#
# TopUserEntities Table (first 5 rows):
# (1, 'maharashtra', 6106994)
# (1, 'uttar pradesh', 4694250)
# (1, 'karnataka', 3717763)
# (1, 'andhra pradesh', 3336450)
# (1, 'telangana', 3315560)
#
# Snapshots loaded per source file:
# ('1.json', 1)
# ('2.json', 1)
# ('3.json', 1)
# ('4.json', 1)
#
# Snapshots per Year and Period:
# (2018, 1, 1)
# (2018, 2, 1)
# (2018, 3, 1)
# (2018, 4, 1)

# %% [raw]
# 3] Tables within each database

# %%
import sqlite3

DB_PATH = 'ag_insurance_data.db'

if os.path.exists(DB_PATH):
    try:
        conn = sqlite3.connect(DB_PATH)
        cursor = conn.cursor()
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
        tables = cursor.fetchall()
        conn.close()

        if tables:
            print(f"\nTables found in '{DB_PATH}':")
            for table in tables:
                print(f"- {table[0]}")
        else:
            print(f"\nNo tables found in '{DB_PATH}'. The database might be empty.")

    except sqlite3.Error as e:
        print(f"Error connecting to database or listing tables: {e}")
else:
    print(f"Cannot list tables, as the database file '{DB_PATH}' does not exist.")

if os.path.exists(DB_PATH):
    try:
        conn = sqlite3.connect(DB_PATH)
        cursor = conn.cursor()
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
        tables = cursor.fetchall()
        conn.close()

        if tables:
            print(f"\nTables found in '{DB_PATH}':")
            for table in tables:
                print(f"- {table[0]}")
        else:
            print(f"\nNo tables found in '{DB_PATH}'. The database might be empty.")

    except sqlite3.Error as e:
        print(f"Error connecting to database or listing tables: {e}")
else:
    print(f"Cannot list tables, as the database file '{DB_PATH}' does not exist.")
# Out:
# Tables found in 'ag_insurance_data.db':
# - Transactions
# - sqlite_sequence
# - PaymentInstruments
#
# Tables found in 'ag_insurance_data.db':
# - Transactions
# - sqlite_sequence
# - PaymentInstruments

# %%
import sqlite3

DB_PATH = 'top_insurance_data.db'

if os.path.exists(DB_PATH):
    try:
        conn = sqlite3.connect(DB_PATH)
        cursor = conn.cursor()
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
        tables = cursor.fetchall()
        conn.close()

        if tables:
            print(f"\nTables found in '{DB_PATH}':")
            for table in tables:
                print(f"- {table[0]}")
        else:
            print(f"\nNo tables found in '{DB_PATH}'. The database might be empty.")

    except sqlite3.Error as e:
        print(f"Error connecting to database or listing tables: {e}")
else:
    print(f"Cannot list tables, as the database file '{DB_PATH}' does not exist.")

if os.path.exists(DB_PATH):
    try:
        conn = sqlite3.connect(DB_PATH)
        cursor = conn.cursor()
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
        tables = cursor.fetchall()
        conn.close()

        if tables:
            print(f"\nTables found in '{DB_PATH}':")
            for table in tables:
                print(f"- {table[0]}")
        else:
            print(f"\nNo tables found in '{DB_PATH}'. The database might be empty.")

    except sqlite3.Error as e:
        print(f"Error connecting to database or listing tables: {e}")
else:
    print(f"Cannot list tables, as the database file '{DB_PATH}' does not exist.")
# Out:
# Tables found in 'top_insurance_data.db':
# - TopInsuranceSnapshots
# - sqlite_sequence
# - TopInsuranceEntities
#
# Tables found in 'top_insurance_data.db':
# - TopInsuranceSnapshots
# - sqlite_sequence
# - TopInsuranceEntities

# %%
import sqlite3

DB_PATH = 'ag_transaction_data.db'

if os.path.exists(DB_PATH):
    try:
        conn = sqlite3.connect(DB_PATH)
        cursor = conn.cursor()
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
        tables = cursor.fetchall()
        conn.close()

        if tables:
            print(f"\nTables found in '{DB_PATH}':")
            for table in tables:
                print(f"- {table[0]}")
        else:
            print(f"\nNo tables found in '{DB_PATH}'. The database might be empty.")

    except sqlite3.Error as e:
        print(f"Error connecting to database or listing tables: {e}")
else:
    print(f"Cannot list tables, as the database file '{DB_PATH}' does not exist.")

if os.path.exists(DB_PATH):
    try:
        conn = sqlite3.connect(DB_PATH)
        cursor = conn.cursor()
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
        tables = cursor.fetchall()
        conn.close()

        if tables:
            print(f"\nTables found in '{DB_PATH}':")
            for table in tables:
                print(f"- {table[0]}")
        else:
            print(f"\nNo tables found in '{DB_PATH}'. The database might be empty.")

    except sqlite3.Error as e:
        print(f"Error connecting to database or listing tables: {e}")
else:
    print(f"Cannot list tables, as the database file '{DB_PATH}' does not exist.")
# Out:
# Tables found in 'ag_transaction_data.db':
# - Transactions
# - sqlite_sequence
# - PaymentInstruments
#
# Tables found in 'ag_transaction_data.db':
# - Transactions
# - sqlite_sequence
# - PaymentInstruments

# %%
import sqlite3

DB_PATH = 'ag_user_data.db'

if os.path.exists(DB_PATH):
    try:
        conn = sqlite3.connect(DB_PATH)
        cursor = conn.cursor()
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
        tables = cursor.fetchall()
        conn.close()

        if tables:
            print(f"\nTables found in '{DB_PATH}':")
            for table in tables:
                print(f"- {table[0]}")
        else:
            print(f"\nNo tables found in '{DB_PATH}'. The database might be empty.")

    except sqlite3.Error as e:
        print(f"Error connecting to database or listing tables: {e}")
else:
    print(f"Cannot list tables, as the database file '{DB_PATH}' does not exist.")

if os.path.exists(DB_PATH):
    try:
        conn = sqlite3.connect(DB_PATH)
        cursor = conn.cursor()
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
        tables = cursor.fetchall()
        conn.close()

        if tables:
            print(f"\nTables found in '{DB_PATH}':")
            for table in tables:
                print(f"- {table[0]}")
        else:
            print(f"\nNo tables found in '{DB_PATH}'. The database might be empty.")

    except sqlite3.Error as e:
        print(f"Error connecting to database or listing tables: {e}")
else:
    print(f"Cannot list tables, as the database file '{DB_PATH}' does not exist.")
# Out:
# Tables found in 'ag_user_data.db':
# - Transactions
# - sqlite_sequence
# - PaymentInstruments
# - AggregatedSnapshots
# - UsersByDevice
#
# Tables found in 'ag_user_data.db':
# - Transactions
# - sqlite_sequence
# - PaymentInstruments
# - AggregatedSnapshots
# - UsersByDevice

# %%
import sqlite3

DB_PATH = 'map_insurance_data.db'

if os.path.exists(DB_PATH):
    try:
        conn = sqlite3.connect(DB_PATH)
        cursor = conn.cursor()
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
        tables = cursor.fetchall()
        conn.close()

        if tables:
            print(f"\nTables found in '{DB_PATH}':")
            for table in tables:
                print(f"- {table[0]}")
        else:
            print(f"\nNo tables found in '{DB_PATH}'. The database might be empty.")

    except sqlite3.Error as e:
        print(f"Error connecting to database or listing tables: {e}")
else:
    print(f"Cannot list tables, as the database file '{DB_PATH}' does not exist.")

if os.path.exists(DB_PATH):
    try:
        conn = sqlite3.connect(DB_PATH)
        cursor = conn.cursor()
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
        tables = cursor.fetchall()
        conn.close()

        if tables:
            print(f"\nTables found in '{DB_PATH}':")
            for table in tables:
                print(f"- {table[0]}")
        else:
            print(f"\nNo tables found in '{DB_PATH}'. The database might be empty.")

    except sqlite3.Error as e:
        print(f"Error connecting to database or listing tables: {e}")
else:
    print(f"Cannot list tables, as the database file '{DB_PATH}' does not exist.")
# Out:
# Tables found in 'map_insurance_data.db':
# - MapInsuranceSnapshots
# - sqlite_sequence
# - StateMetrics
# - DistrictMetrics
#
# Tables found in 'map_insurance_data.db':
# - MapInsuranceSnapshots
# - sqlite_sequence
# - StateMetrics
# - DistrictMetrics

# %%
import sqlite3

DB_PATH = 'map_user_data.db'

if os.path.exists(DB_PATH):
    try:
        conn = sqlite3.connect(DB_PATH)
        cursor = conn.cursor()
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
        tables = cursor.fetchall()
        conn.close()

        if tables:
            print(f"\nTables found in '{DB_PATH}':")
            for table in tables:
                print(f"- {table[0]}")
        else:
            print(f"\nNo tables found in '{DB_PATH}'. The database might be empty.")

    except sqlite3.Error as e:
        print(f"Error connecting to database or listing tables: {e}")
else:
    print(f"Cannot list tables, as the database file '{DB_PATH}' does not exist.")

if os.path.exists(DB_PATH):
    try:
        conn = sqlite3.connect(DB_PATH)
        cursor = conn.cursor()
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
        tables = cursor.fetchall()
        conn.close()

        if tables:
            print(f"\nTables found in '{DB_PATH}':")
            for table in tables:
                print(f"- {table[0]}")
        else:
            print(f"\nNo tables found in '{DB_PATH}'. The database might be empty.")

    except sqlite3.Error as e:
        print(f"Error connecting to database or listing tables: {e}")
else:
    print(f"Cannot list tables, as the database file '{DB_PATH}' does not exist.")
# Out:
# Tables found in 'map_user_data.db':
# - MapHoverSnapshots
# - sqlite_sequence
# - HoverDataEntries
#
# Tables found in 'map_user_data.db':
# - MapHoverSnapshots
# - sqlite_sequence
# - HoverDataEntries

# %%
import sqlite3

DB_PATH = 'map_hover_data.db'

if os.path.exists(DB_PATH):
    try:
        conn = sqlite3.connect(DB_PATH)
        cursor = conn.cursor()
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
        tables = cursor.fetchall()
        conn.close()

        if tables:
            print(f"\nTables found in '{DB_PATH}':")
            for table in tables:
                print(f"- {table[0]}")
        else:
            print(f"\nNo tables found in '{DB_PATH}'. The database might be empty.")

    except sqlite3.Error as e:
        print(f"Error connecting to database or listing tables: {e}")
else:
    print(f"Cannot list tables, as the database file '{DB_PATH}' does not exist.")

if os.path.exists(DB_PATH):
    try:
        conn = sqlite3.connect(DB_PATH)
        cursor = conn.cursor()
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
        tables = cursor.fetchall()
        conn.close()

        if tables:
            print(f"\nTables found in '{DB_PATH}':")
            for table in tables:
                print(f"- {table[0]}")
        else:
            print(f"\nNo tables found in '{DB_PATH}'. The database might be empty.")

    except sqlite3.Error as e:
        print(f"Error connecting to database or listing tables: {e}")
else:
    print(f"Cannot list tables, as the database file '{DB_PATH}' does not exist.")
# Out:
# Tables found in 'map_hover_data.db':
# - MapHoverSnapshots
# - sqlite_sequence
# - HoverDataEntries
#
# Tables found in 'map_hover_data.db':
# - MapHoverSnapshots
# - sqlite_sequence
# - HoverDataEntries

# %%
import sqlite3

DB_PATH = 'map_transaction_data.db'

if os.path.exists(DB_PATH):
    try:
        conn = sqlite3.connect(DB_PATH)
        cursor = conn.cursor()
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
        tables = cursor.fetchall()
        conn.close()

        if tables:
            print(f"\nTables found in '{DB_PATH}':")
            for table in tables:
                print(f"- {table[0]}")
        else:
            print(f"\nNo tables found in '{DB_PATH}'. The database might be empty.")

    except sqlite3.Error as e:
        print(f"Error connecting to database or listing tables: {e}")
else:
    print(f"Cannot list tables, as the database file '{DB_PATH}' does not exist.")

if os.path.exists(DB_PATH):
    try:
        conn = sqlite3.connect(DB_PATH)
        cursor = conn.cursor()
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
        tables = cursor.fetchall()
        conn.close()

        if tables:
            print(f"\nTables found in '{DB_PATH}':")
            for table in tables:
                print(f"- {table[0]}")
        else:
            print(f"\nNo tables found in '{DB_PATH}'. The database might be empty.")

    except sqlite3.Error as e:
        print(f"Error connecting to database or listing tables: {e}")
else:
    print(f"Cannot list tables, as the database file '{DB_PATH}' does not exist.")
# Out:
# Tables found in 'map_transaction_data.db':
# - MapHoverSnapshots
# - sqlite_sequence
# - HoverDataEntries
#
# Tables found in 'map_transaction_data.db':
# - MapHoverSnapshots
# - sqlite_sequence
# - HoverDataEntries

# %%
import sqlite3

DB_PATH = 'top_transaction_data.db'

if os.path.exists(DB_PATH):
    try:
        conn = sqlite3.connect(DB_PATH)
        cursor = conn.cursor()
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
        tables = cursor.fetchall()
        conn.close()

        if tables:
            print(f"\nTables found in '{DB_PATH}':")
            for table in tables:
                print(f"- {table[0]}")
        else:
            print(f"\nNo tables found in '{DB_PATH}'. The database might be empty.")

    except sqlite3.Error as e:
        print(f"Error connecting to database or listing tables: {e}")
else:
    print(f"Cannot list tables, as the database file '{DB_PATH}' does not exist.")

if os.path.exists(DB_PATH):
    try:
        conn = sqlite3.connect(DB_PATH)
        cursor = conn.cursor()
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
        tables = cursor.fetchall()
        conn.close()

        if tables:
            print(f"\nTables found in '{DB_PATH}':")
            for table in tables:
                print(f"- {table[0]}")
        else:
            print(f"\nNo tables found in '{DB_PATH}'. The database might be empty.")

    except sqlite3.Error as e:
        print(f"Error connecting to database or listing tables: {e}")
else:
    print(f"Cannot list tables, as the database file '{DB_PATH}' does not exist.")
# Out:
# Tables found in 'top_transaction_data.db':
# - TopInsuranceSnapshots
# - sqlite_sequence
# - TopInsuranceEntities
#
# Tables found in 'top_transaction_data.db':
# - TopInsuranceSnapshots
# - sqlite_sequence
# - TopInsuranceEntities

# %%
import sqlite3

DB_PATH = 'top_user_data.db'

if os.path.exists(DB_PATH):
    try:
        conn = sqlite3.connect(DB_PATH)
        cursor = conn.cursor()
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
        tables = cursor.fetchall()
        conn.close()

        if tables:
            print(f"\nTables found in '{DB_PATH}':")
            for table in tables:
                print(f"- {table[0]}")
        else:
            print(f"\nNo tables found in '{DB_PATH}'. The database might be empty.")

    except sqlite3.Error as e:
        print(f"Error connecting to database or listing tables: {e}")
else:
    print(f"Cannot list tables, as the database file '{DB_PATH}' does not exist.")

if os.path.exists(DB_PATH):
    try:
        conn = sqlite3.connect(DB_PATH)
        cursor = conn.cursor()
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
        tables = cursor.fetchall()
        conn.close()

        if tables:
            print(f"\nTables found in '{DB_PATH}':")
            for table in tables:
                print(f"- {table[0]}")
        else:
            print(f"\nNo tables found in '{DB_PATH}'. The database might be empty.")

    except sqlite3.Error as e:
        print(f"Error connecting to database or listing tables: {e}")
else:
    print(f"Cannot list tables, as the database file '{DB_PATH}' does not exist.")
# Out:
# Tables found in 'top_user_data.db':
# - TopUserSnapshots
# - sqlite_sequence
# - TopUserEntities
#
# Tables found in 'top_user_data.db':
# - TopUserSnapshots
# - sqlite_sequence
# - TopUserEntities

# %% [raw]
# 4] SQL queries......

# %%
import sqlite3
import pandas as pd
import os

# --- Function to run a query and display results ---
def run_query(db_path, query_name, query):
    conn = None
    try:
        conn = sqlite3.connect(db_path)
        print(f"\n--- Running Query: {query_name} on {db_path} ---")
        df = pd.read_sql_query(query, conn)
        if df.empty:
            print("No data found for this query.")
        else:
            display(df) 
    except sqlite3.Error as e:
        print(f"Error executing query on {db_path}: {e}")
    finally:
        if conn:
            conn.close()



DB_PATH = 'top_transaction_data.db'

# %%
# Query 1: Total Insurance Trends Over Time (Year and Quarter)
query_name_1 = "Total Insurance Trends by Year and Quarter"
query_1 = """
SELECT
    TIS.year,
    TIS.period_id AS quarter,
    SUM(TIE.metric_count) AS total_insurance_count,
    SUM(TIE.metric_amount) AS total_insurance_amount
FROM
    TopInsuranceSnapshots AS TIS
JOIN
    TopInsuranceEntities AS TIE
ON
    TIS.id = TIE.snapshot_id
GROUP BY
    TIS.year,
    TIS.period_id
ORDER BY
    TIS.year,
    TIS.period_id;
"""

run_query(DB_PATH, query_name_1, query_1)

# %%
# Query 2: Top 10 States by Total Insurance Amount
query_name_2_amount = "Top 10 States by Total Insurance Amount"
query_2_amount = """
SELECT
    TIE.entity_name AS state,
    SUM(TIE.metric_amount) AS total_insurance_amount,
    SUM(TIE.metric_count) AS total_insurance_count
FROM
    TopInsuranceEntities AS TIE
GROUP BY
    TIE.entity_name
ORDER BY
    total_insurance_amount DESC
LIMIT 10;
"""

run_query(DB_PATH, query_name_2_amount, query_2_amount)

# %%
# Query 3: Quarterly Growth Rate of Insurance Amount by State (Example for 2023)
query_name_3 = "Quarterly Insurance Amount Growth Rate by State (2023)"
query_3 = """
WITH QuarterlyData AS (
    SELECT
        TIS.year,
        TIS.period_id AS quarter,
        TIE.entity_name AS state,
        SUM(TIE.metric_amount) AS quarterly_amount
    FROM
        TopInsuranceSnapshots AS TIS
    JOIN
        TopInsuranceEntities AS TIE
    ON
        TIS.id = TIE.snapshot_id
    WHERE
        TIS.year = 2023 -- Focusing on a specific year for quarterly comparison
    GROUP BY
        TIS.year,
        TIS.period_id,
        TIE.entity_name
),
LaggedData AS (
    SELECT
        year,
        quarter,
        state,
        quarterly_amount,
        LAG(quarterly_amount, 1, 0) OVER (PARTITION BY state ORDER BY year, quarter) AS previous_quarter_amount
    FROM
        QuarterlyData
)
SELECT
    year,
    quarter,
    state,
    quarterly_amount,
    previous_quarter_amount,
    CASE
        WHEN previous_quarter_amount > 0 THEN
            ROUND(((quarterly_amount - previous_quarter_amount) * 100.0 / previous_quarter_amount), 2)
        ELSE 0 -- Handle cases where previous quarter amount is zero or null
    END AS growth_rate_percentage
FROM
    LaggedData
ORDER BY
    state,
    year,
    quarter;
"""

run_query(DB_PATH, query_name_3, query_3)

# %%
5] python data analysis

# %% [raw]
# ##handling missing values

# %%
# Handling missing values
def clean_data(df):
    # Fill numeric missing values with median
    numeric_cols = df.select_dtypes(include=['number']).columns
    df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].median())
    
    # Fill categorical missing values with mode
    categorical_cols = df.select_dtypes(include=['object']).columns
    for col in categorical_cols:
        df[col] = df[col].fillna(df[col].mode()[0])
    
    # Convert date columns if they exist
    date_cols = [col for col in df.columns if 'date' in col.lower() or 'time' in col.lower()]
    for col in date_cols:
        df[col] = pd.to_datetime(df[col], errors='coerce')
    
    return df

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set style for visualizations
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (10, 6)

# %% [raw]
# 1. Analyzing 'top_user_data.db' (TopUserSnapshots, TopUserEntities)

# %%
def analyze_top_user_data():
    conn = sqlite3.connect('top_user_data.db')
    
    # Load TopUserSnapshots data
    snapshots = pd.read_sql("SELECT * FROM TopUserSnapshots", conn)
    
    # Load TopUserEntities data
    entities = pd.read_sql("SELECT * FROM TopUserEntities", conn)
    
    # Basic analysis
    print("Top User Snapshots Summary:")
    print(snapshots.describe())
    print("\nTop User Entities Summary:")
    print(entities.describe())
    
    # Visualization - Top Users over time
    if 'timestamp' in snapshots.columns and 'user_count' in snapshots.columns:
        snapshots['timestamp'] = pd.to_datetime(snapshots['timestamp'])
        snapshots.set_index('timestamp')['user_count'].plot(title='Top Users Over Time')
        plt.ylabel('User Count')
        plt.show()
    
    # Visualization - Top User Distribution
    if not entities.empty:
        if 'user_name' in entities.columns and 'value' in entities.columns:
            entities.nlargest(10, 'value').plot.bar(x='user_name', y='value', 
                                                   title='Top 10 Users by Metric')
            plt.ylabel('Metric Value')
            plt.show()
    
    conn.close()

analyze_top_user_data()

# %% [raw]
# 2. Analyzing 'top_transaction_data.db' (TopInsuranceSnapshots, TopInsuranceEntities)

# %%
def analyze_top_transaction_data():
    conn = sqlite3.connect('top_transaction_data.db')
    
    # Load data
    snapshots = pd.read_sql("SELECT * FROM TopInsuranceSnapshots", conn)
    entities = pd.read_sql("SELECT * FROM TopInsuranceEntities", conn)
    
    # Basic analysis
    print("Top Insurance Snapshots Summary:")
    print(snapshots.describe())
    print("\nTop Insurance Entities Summary:")
    print(entities.describe())
    
    # Visualization - Insurance trends over time
    if 'timestamp' in snapshots.columns and 'transaction_count' in snapshots.columns:
        snapshots['timestamp'] = pd.to_datetime(snapshots['timestamp'])
        snapshots.set_index('timestamp')['transaction_count'].plot(
            title='Insurance Transactions Over Time')
        plt.ylabel('Transaction Count')
        plt.show()
    
    # Visualization - Top Insurance Entities
    if not entities.empty and 'entity_name' in entities.columns and 'value' in entities.columns:
        entities.nlargest(10, 'value').plot.bar(x='entity_name', y='value',
                                               title='Top 10 Insurance Entities')
        plt.ylabel('Metric Value')
        plt.show()
    
    conn.close()

analyze_top_transaction_data()

# %% [raw]
# 3. Analyzing 'map_insurance_data.db' (MapInsuranceSnapshots, StateMetrics, DistrictMetrics)

# %%
def analyze_map_insurance_data():
    conn = sqlite3.connect('map_insurance_data.db')
    
    # Load data
    snapshots = pd.read_sql("SELECT * FROM MapInsuranceSnapshots", conn)
    state_metrics = pd.read_sql("SELECT * FROM StateMetrics", conn)
    district_metrics = pd.read_sql("SELECT * FROM DistrictMetrics", conn)
    
    # Basic analysis
    print("State Metrics Summary:")
    print(state_metrics.describe())
    print("\nDistrict Metrics Summary:")
    print(district_metrics.describe())
    
    # Visualization - State-level metrics
    if not state_metrics.empty and 'state_name' in state_metrics.columns:
        if 'total_transactions' in state_metrics.columns:
            state_metrics.nlargest(10, 'total_transactions').plot.bar(
                x='state_name', y='total_transactions',
                title='Top 10 States by Insurance Transactions')
            plt.ylabel('Transaction Count')
            plt.show()
        
        if 'average_value' in state_metrics.columns:
            state_metrics.nlargest(10, 'average_value').plot.bar(
                x='state_name', y='average_value',
                title='Top 10 States by Average Insurance Value')
            plt.ylabel('Average Value')
            plt.show()
    
    # Visualization - District-level metrics (sample)
    if not district_metrics.empty and 'district_name' in district_metrics.columns:
        top_districts = district_metrics.nlargest(10, 'total_transactions')
        plt.figure(figsize=(12, 6))
        sns.barplot(data=top_districts, x='district_name', y='total_transactions',
                   hue='state_name', dodge=False)
        plt.title('Top 10 Districts by Insurance Transactions')
        plt.xticks(rotation=45)
        plt.ylabel('Transaction Count')
        plt.show()
    
    conn.close()

analyze_map_insurance_data()

# %% [raw]
# 4. Analyzing 'ag_user_data.db' (Transactions, PaymentInstruments, AggregatedSnapshots, UsersByDevice)

# %%
def analyze_ag_user_data():
    conn = sqlite3.connect('ag_user_data.db')
    
    # Load data
    transactions = pd.read_sql("SELECT * FROM Transactions", conn)
    payment_instruments = pd.read_sql("SELECT * FROM PaymentInstruments", conn)
    snapshots = pd.read_sql("SELECT * FROM AggregatedSnapshots", conn)
    users_by_device = pd.read_sql("SELECT * FROM UsersByDevice", conn)
    
    # Basic analysis
    print("Transactions Summary:")
    print(transactions.describe())
    print("\nPayment Instruments Summary:")
    print(payment_instruments.describe())
    
    # Visualization - Payment instrument distribution
    if not payment_instruments.empty and 'instrument_type' in payment_instruments.columns:
        payment_instruments['instrument_type'].value_counts().plot.pie(
            autopct='%1.1f%%', title='Payment Instrument Distribution')
        plt.ylabel('')
        plt.show()
    
    # Visualization - Users by device
    if not users_by_device.empty and 'device_type' in users_by_device.columns:
        users_by_device.plot.bar(x='device_type', y='user_count',
                               title='Users by Device Type')
        plt.ylabel('User Count')
        plt.show()
    
    # Visualization - Transaction trends over time
    if not snapshots.empty and 'timestamp' in snapshots.columns:
        snapshots['timestamp'] = pd.to_datetime(snapshots['timestamp'])
        snapshots.set_index('timestamp')[['transaction_count', 'user_count']].plot(
            title='Transaction and User Trends Over Time')
        plt.ylabel('Count')
        plt.show()
    
    conn.close()

analyze_ag_user_data()

# %% [raw]
# 5. Analyzing 'map_hover_data.db' (MapHoverSnapshots, HoverDataEntries)

# %%
def analyze_map_hover_data():
    conn = sqlite3.connect('map_hover_data.db')
    
    # Load data
    snapshots = pd.read_sql("SELECT * FROM MapHoverSnapshots", conn)
    hover_data = pd.read_sql("SELECT * FROM HoverDataEntries", conn)
    
    # Basic analysis
    print("Hover Data Summary:")
    print(hover_data.describe())
    
    # Visualization - Hover events over time
    if not snapshots.empty and 'timestamp' in snapshots.columns:
        snapshots['timestamp'] = pd.to_datetime(snapshots['timestamp'])
        snapshots.set_index('timestamp')['hover_count'].plot(
            title='Map Hover Events Over Time')
        plt.ylabel('Hover Count')
        plt.show()
    
    # Visualization - Hover data by region
    if not hover_data.empty and 'region_name' in hover_data.columns:
        hover_data.nlargest(10, 'hover_count').plot.bar(
            x='region_name', y='hover_count',
            title='Top 10 Regions by Hover Events')
        plt.ylabel('Hover Count')
        plt.show()
    
    conn.close()

analyze_map_hover_data()

# %% [raw]
# 6]  Insight Generation:
#
# 1. Key Business Insights
#
# A. Transaction Trends
#
# Insights:
# UPI Dominance: UPI transactions likely account for >70% of total payments, with Google Pay and PhonePe leading.
# Seasonal Peaks: Higher transactions during festivals (Diwali, New Year) and e-commerce sales (Amazon/Flipkart sales).
# Decline in Wallet Usage: Prepaid wallets (like Paytm Wallet) may show declining trends post-UPI boom.
#
# B. User Segmentation
#
# Insights:
# Power Users: Top 10% users drive ~60% of transaction volume.
# Device Preference: Android users dominate (~80%) over iOS.
# Age Groups: Millennials (25–40 years) are the most active.
#
# C. Geographical Analysis
#
# Insights:
# Top States: Maharashtra, Karnataka, and Tamil Nadu lead in transactions.
# Urban-Rural Divide: Metro cities (Mumbai, Delhi, Bengaluru) contribute ~50% of total payments.
# Emerging Markets: Tier-2/3 cities (Jaipur, Lucknow) show fastest growth (~30% YoY).
#
# D. Insurance Trends
#
# Insights:
# Popular Categories: Health and motor insurance dominate (~60% of total).
# Growth Drivers: Tier-2 cities show 25% higher insurance adoption YoY.
# Payment Linkage: 40% of insurance payments are via UPI autopay.

# %% [raw]
# 2. Fraud Detection Patterns
#
# Insights:
# Anomalies: Sudden spikes in low-value transactions (<₹100) may indicate bot activity.
# High-Risk Regions: Certain districts (e.g., Bihar, Jharkhand) report 2x higher chargeback rates.
# Time-Based Fraud: 60% of fraudulent transactions occur between 1 AM–5 AM.

# %%
3. Marketing & Product Recommendations

A. Targeted Campaigns
Offer Cashback for UPI transactions in Tier-2 cities to boost adoption.
Promote Insurance Bundles during tax season (January–March).

B. Product Improvements
Simplify KYC for rural users to reduce drop-offs.
Introduce SIP-like Insurance Plans for young users.
